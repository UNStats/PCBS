# %% [markdown]
# # Development of SDG Matrix for PCBS

# %% [markdown]
# The may objective of the UNSD/DFID project technical mission to PCBS (from 31 March to 4 April 2019) is to support PCBS in setting up:
# - A working prototype of an SDG data platform
# - A workflow to update and maintain the SDG data platform prototype using, as much as possible, automation tools
#
# **Deliverables:**
# 1. A national SDG indicators matrix
#    - Indicator name
#    - Mapping to global SDG indicator framework
#    - Source
#    - Availability
# 2. A national SDG data structure definition
#    - Indicator code
#    - Indicator description
#    - Available disaggregations (dimensions)
#    - Available attributes
# 3. Data collection and validation templates
# 4. A repository of available SDG data,  including:
#    - A master version of the national DSD and Code Lists
#    - Set of SDG indicator tables following the national DSD
#    - Pivot/extended views of the SDG indicator tables, suitable for data dissemination
# 5. A repository of boundary data for the available geographic disaggregations
# 6. A repository of core metadata files and graphic design assets
# 7. A repository of python scripts for dataflow automation, which may include:
#    - Data pre-processing
#    - Creation of pivot/extended views of the SDG indicator tables for dissemination
#    - Linking of SDG indicator tables with geographic boundaries and publication into ArcGIS online

# %% [markdown]
# ## 1. Setup of working environment for this notebook

# %%
import pandas as pd
import os 

dir_path = os.path.dirname(os.path.realpath('__file__'))
print(dir_path)


input_dir = r'../SDG-Matrix/Input/'
print('data inputs dir: ' + input_dir)

output_dir = r'../SDG-Matrix/Output/'
print('outputs dir: ' + output_dir)
# Out:
# C:\Users\L.GonzalezMorales\Documents\GitHub\PCBS\notebooks
# data inputs dir: ../SDG-Matrix/Input/
# outputs dir: ../SDG-Matrix/Output/

# %% [markdown]
# ## 2. Develop SDG Matrix template

# %% [markdown]
# ## 2.1 Read `SDGsMatrix.csv` file provided by PCBS
#
# The `SDGsMatrix.csv` file contains the list of all SDG indicators

# %%
sdgMatrix_df = pd.read_csv(input_dir + 'SDGsMatrix.csv', encoding='UTF-8', 
                              dtype={'Goal_ID':str,
                                     'Goal_DescEn':str,
                                     'Goal_DescAr':str,
                                     'Target_ID':str,
                                     'Target_DescEn':str,
                                     'Target_DescAr': str,
                                     'Indicator_NL': str,
                                     'Indicator_Code': str,
                                     'Indicator_descEn': str,
                                     'Indicator_descAr': str,
                                     'Subindicator_Code': str, 
                                     'Subindicator_DescEn': str,
                                     'Subindicator_DescAr': str })
sdgMatrix_df.head(5)
# Out:
#   Goal_ID Goal_DescEn       Goal_DescAr Target_ID  \
# 0       1  No poverty  القضاء على الفقر       1.1
# 1       1  No poverty  القضاء على الفقر       1.1
# 2       1  No poverty  القضاء على الفقر       1.1
# 3       1  No poverty  القضاء على الفقر       1.1
# 4       1  No poverty  القضاء على الفقر       1.1
#
#                                        Target_DescEn  \
# 0  By 2030, eradicate extreme poverty for all peo...
# 1  By 2030, eradicate extreme poverty for all peo...
# 2  By 2030, eradicate extreme poverty for all peo...
# 3  By 2030, eradicate extreme poverty for all peo...
# 4  By 2030, eradicate extreme poverty for all peo...
#
#                                        Target_DescAr Indicator_NL  \
# 0  القضاء على الفقر المدقع للناس أجمعين أينما كان...   1.1.1
# 1  القضاء على الفقر المدقع للناس أجمعين أينما كان...   1.1.1
# 2  القضاء على الفقر المدقع للناس أجمعين أينما كان...   1.1.1
# 3  القضاء على الفقر المدقع للناس أجمعين أينما كان...   1.1.1
# 4  القضاء على الفقر المدقع للناس أجمعين أينما كان...   1.1.1
#
#   Indicator_Code                                   Indicator_descEn  \
# 0     C010101      Proportion of population below the internatio...
# 1     C010101      Proportion of population below the internatio...
# 2     C010101      Proportion of population below the internatio...
# 3     C010101      Proportion of population below the internatio...
# 4     C010101      Proportion of population below the internatio...
#
#                                     Indicator_descAr      ...        \
# 0  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 1  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 2  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 3  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 4  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
#
#   InternetSpeed_DescEn InternetSpeed_DescAr OBS_VALUE  UNIT_MULT  \
# 0                  NaN                  NaN       NaN        NaN
# 1                  NaN                  NaN       NaN        NaN
# 2                  NaN                  NaN       NaN        NaN
# 3                  NaN                  NaN       NaN        NaN
# 4                  NaN                  NaN       NaN        NaN
#
#    UNIT_MEASURE OBS_STATUS  TIME_DETAIL COMMENT_OBS BASE_PER  SOURCE_DETAIL
# 0           NaN        NaN          NaN         NaN      NaN            NaN
# 1           NaN        NaN          NaN         NaN      NaN            NaN
# 2           NaN        NaN          NaN         NaN      NaN            NaN
# 3           NaN        NaN          NaN         NaN      NaN            NaN
# 4           NaN        NaN          NaN         NaN      NaN            NaN
#
# [5 rows x 76 columns]

# %% [markdown]
# *Check number of rows and columns:*

# %%
print(sdgMatrix_df.shape)
print(sdgMatrix_df.columns)
# Out:
# (47439, 76)
# Index(['Goal_ID', 'Goal_DescEn', 'Goal_DescAr', 'Target_ID', 'Target_DescEn',
#        'Target_DescAr', 'Indicator_NL', 'Indicator_Code', 'Indicator_descEn',
#        'Indicator_descAr', 'Subindicator_Code', 'Subindicator_DescEn',
#        'Subindicator_DescAr', 'TIME_PERIOD', 'REF_AREA', 'REF_AREA_DESC_EN',
#        'REF_AREA_DESC_AR', 'SEX', 'SEX_DESC_EN', 'SEX_DESC_AR', 'AGE',
#        'Age_DescEn', 'Age_DescAr', 'URBANISATION', 'Urbanisation_DescEn',
#        'Urbanisation_DescAr', 'EDUCATION_LEV', 'Education_DescEn',
#        'Education_DescAr', 'DISABILITY_STATUS', 'DisabilityStatus_DescEn',
#        'DisabilityStatus_DescAr', 'OCCUPATION', 'Occupation_DescEn',
#        'Occupation_DescAr', 'Sector', 'Sector_DescEn', 'Sector_DescAr',
#        'AreaOfStudy', 'AreaOfStudy_DescEn', 'AreaOfStudy_DescAr',
#        'TypeOfViolence', 'TypeOfViolence_DescEn', 'TypeOfViolence_DescAr',
#        'EmploymentStatus', 'EmploymentStatus_DescEn',
#        'EmploymentStatus_DescAr', 'PregnancyStatus', 'PregnancyStatus_DescEn',
#        'PregnancyStatus_DescAr', 'WorkingInjuryStatus',
#        'WorkingInjuryStatus_DescEn', 'WorkingInjuryStatus_DescAr',
#        'PovertyStatus', 'PovertyStatus_DescEn', 'PovertyStatus_DescAr',
#        'YearsOfSchooling', 'YearsOfSchooling_DescEn',
#        'YearsOfSchooling_DescAr', 'MobileNetworkTechnology',
#        'MobileNetworkTechnology_DescEn', 'MobileNetworkTechnology_DescAr',
#        'EcosystemType', 'EcosystemType_DescEn', 'EcosystemType_DescAr',
#        'InternetSpeed', 'InternetSpeed_DescEn', 'InternetSpeed_DescAr',
#        'OBS_VALUE', 'UNIT_MULT', 'UNIT_MEASURE', 'OBS_STATUS', 'TIME_DETAIL',
#        'COMMENT_OBS', 'BASE_PER', 'SOURCE_DETAIL'],
#       dtype='object')

# %% [markdown]
# ## 2.2 Identify dimensions
#
# The template includes 18 coded dimensions (in addition to **`TIME_PERIOD`**), namely:
# - **`REF_AREA`**: Reference area (geographic area)
# - **`SEX`**: Male/female
# - **`URBANISATION`**: Urban/rural
# - **`EDUCATION_LEV`**: Education level
# - **`DISABILITY_STATUS`**: Disability status
# - **`OCCUPATION`**: Occupation
# - **`SECTOR`**: Economic activity
# - **`STUDY_AREA`**: Area of study
# - **`VIOLENCE_TYPE`**: Type of violence
# - **`EMPLOYMENT_STATUS`**: Employment status
# - **`PREGNANCY_STATUS`**: Pregnancy status
# - **`WORKING_INJURY_STATUS`**: Working injury status
# - **`POVERTY_STATUS`**: Poverty status
# - **`SCHOOLING_YEARS`**: Years of schooling
# - **`MOBILE_NETWORK_TECHNOLOGY`**: Mobile network technology
# - **`ECOSYSTEM_TYPE`**: Type of ecosystem
# - **`INTERNET_SPEED`**: Internet speed
#
# In addition to the dimension codes, the matrix also includes English and Arabic description for each of them.

# %%
dimensions = [
    {
     'dimension_code' : 'REF_AREA',
     'dimension_name' : 'Reference area (geographic area)'
},{
     'dimension_code' : 'SEX',
     'dimension_name' : 'Male/female'
},{
     'dimension_code' : 'URBANISATION',
     'dimension_name' : 'Urban/rural'
},{
     'dimension_code' : 'EDUCATION_LEV',
     'dimension_name' : 'Education level'
},{
     'dimension_code' : 'DISABILITY_STATUS',
     'dimension_name' : 'Disability status'
},{
     'dimension_code' : 'OCCUPATION',
     'dimension_name' : 'Occupation'
},{
     'dimension_code' : 'SECTOR',
     'dimension_name' : 'Economic activity'
},{
     'dimension_code' : 'STUDY_AREA',
     'dimension_name' : 'Area of study'
},{
     'dimension_code' : 'VIOLENCE_TYPE',
     'dimension_name' : 'Type of violence'
},{
     'dimension_code' : 'EMPLOYMENT_STATUS',
     'dimension_name' : 'Employment status'
},{
     'dimension_code' : 'PREGNANCY_STATUS',
     'dimension_name' : 'Pregnancy status'
},{
     'dimension_code' : 'WORKING_INJURY_STATUS',
     'dimension_name' : 'Working injury status'
},{
     'dimension_code' : 'POVERTY_STATUS',
     'dimension_name' : 'Poverty status'
},{
     'dimension_code' : 'SCHOOLING_YEARS',
     'dimension_name' : 'Years of schooling'
},{
     'dimension_code' : 'MOBILE_NETWORK_TECHNOLOGY',
     'dimension_name' : 'Mobile network technology'
},{
     'dimension_code' : 'ECOSYSTEM_TYPE',
     'dimension_name' : 'Type of ecosystem'
},{
     'dimension_code' : 'INTERNET_SPEED',
     'dimension_name' : 'Internet speed'
}]

# %% [markdown]
# ### 2.2.a Standardize For the sake of standardization, the dimension columns of the draft matrix will be written in all-capital letters:

# %%
sdgMatrix_df = sdgMatrix_df.rename(columns = {'Age_DescEn':'AGE_DESC_EN', 
                                                    'Age_DescAr':'AGE_DESC_AR',
                                                    'Urbanisation_DescEn': 'URBANISATION_DESC_EN', 
                                                    'Urbanisation_DescAr': 'URBANISATION_DESC_AR',
                                                    'Education_DescEn': 'EDUCATION_LEV_DESC_EN', 
                                                    'Education_DescAr': 'EDUCATION_LEV_DESC_AR',
                                                    'DisabilityStatus_DescEn': 'DISABILITY_STATUS_DESC_EN', 
                                                    'DisabilityStatus_DescAr': 'DISABILITY_STATUS_DESC_AR',
                                                    'Occupation_DescEn': 'OCCUPATION_DESC_EN', 
                                                    'Occupation_DescAr': 'OCCUPATION_DESC_AR',
                                                    'Sector': 'SECTOR', 
                                                    'Sector_DescEn': 'SECTOR_DESC_EN', 
                                                    'Sector_DescAr': 'SECTOR_DESC_AR',
                                                    'AreaOfStudy': 'STUDY_AREA', 
                                                    'AreaOfStudy_DescEn': 'STUDY_AREA_DESC_EN', 
                                                    'AreaOfStudy_DescAr': 'STUDY_AREA_DESC_AR',
                                                    'TypeOfViolence': 'VIOLENCE_TYPE', 
                                                    'TypeOfViolence_DescEn': 'VIOLENCE_TYPE_DESC_EN', 
                                                    'TypeOfViolence_DescAr': 'VIOLENCE_TYPE_DESC_AR',
                                                    'EmploymentStatus': 'EMPLOYMENT_STATUS', 
                                                    'EmploymentStatus_DescEn': 'EMPLOYMENT_STATUS_DESC_EN', 
                                                    'EmploymentStatus_DescAr': 'EMPLOYMENT_STATUS_DESC_AR', 
                                                    'PregnancyStatus': 'PREGNANCY_STATUS', 
                                                    'PregnancyStatus_DescEn': 'PREGNANCY_STATUS_DESC_EN', 
                                                    'PregnancyStatus_DescAr': 'PREGNANCY_STATUS_DESC_AR',
                                                    'WorkingInjuryStatus': 'WORKING_INJURY_STATUS', 
                                                    'WorkingInjuryStatus_DescEn': 'WORKING_INJURY_STATUS_DESC_EN', 
                                                    'WorkingInjuryStatus_DescAr': 'WORKING_INJURY_STATUS_DESC_AR',
                                                    'PovertyStatus': 'POVERTY_STATUS', 
                                                    'PovertyStatus_DescEn': 'POVERTY_STATUS_DESC_EN', 
                                                    'PovertyStatus_DescAr': 'POVERTY_STATUS_DESC_AR',
                                                    'YearsOfSchooling': 'SCHOOLING_YEARS', 
                                                    'YearsOfSchooling_DescEn': 'SCHOOLING_YEARS_DESC_EN', 
                                                    'YearsOfSchooling_DescAr': 'SCHOOLING_YEARS_DESC_AR', 
                                                    'MobileNetworkTechnology': 'MOBILE_NETWORK_TECHNOLOGY', 
                                                    'MobileNetworkTechnology_DescEn': 'MOBILE_NETWORK_TECHNOLOGY_DESC_EN', 
                                                    'MobileNetworkTechnology_DescAr': 'MOBILE_NETWORK_TECHNOLOGY_DESC_AR',
                                                    'EcosystemType': 'ECOSYSTEM_TYPE', 
                                                    'EcosystemType_DescEn': 'ECOSYSTEM_TYPE_DESC_EN', 
                                                    'EcosystemType_DescAr': 'ECOSYSTEM_TYPE_DESC_AR',
                                                    'InternetSpeed': 'INTERNET_SPEED', 
                                                    'InternetSpeed_DescEn': 'INTERNET_SPEED_DESC_EN', 
                                                    'InternetSpeed_DescAr': 'INTERNET_SPEED_DESC_AR'})

# %% [markdown]
# Similarly, use capital letter for all other column headings:

# %%
sdgMatrix_df = sdgMatrix_df.rename(columns = {'Goal_ID': 'GOAL_ID', 
                                              'Goal_DescEn': 'GOAL_DESC_EN', 
                                              'Goal_DescAr': 'GOAL_DESC_AR',
                                              'Target_ID': 'TARGET_ID', 
                                              'Target_DescEn': 'TARGET_DESC_EN',
                                              'Target_DescAr': 'TARGET_DESC_AR', 
                                              'Indicator_NL': 'INDICATOR_LABEL', 
                                              'Indicator_Code': 'INDICATOR_ID', 
                                              'Indicator_descEn': 'INDICATOR_DESC_EN',
                                              'Indicator_descAr': 'INDICATOR_DESC_AR', 
                                              'Subindicator_Code': 'SUBINDICATOR_ID',
                                              'Subindicator_DescEn': 'SUBINDICATOR_DESC_EN',
                                              'Subindicator_DescAr': 'SUBINDICATOR_DESC_AR'})

# %%
sdgMatrix_df.head(5)
# Out:
#   GOAL_ID GOAL_DESC_EN      GOAL_DESC_AR TARGET_ID  \
# 0       1   No poverty  القضاء على الفقر       1.1
# 1       1   No poverty  القضاء على الفقر       1.1
# 2       1   No poverty  القضاء على الفقر       1.1
# 3       1   No poverty  القضاء على الفقر       1.1
# 4       1   No poverty  القضاء على الفقر       1.1
#
#                                       TARGET_DESC_EN  \
# 0  By 2030, eradicate extreme poverty for all peo...
# 1  By 2030, eradicate extreme poverty for all peo...
# 2  By 2030, eradicate extreme poverty for all peo...
# 3  By 2030, eradicate extreme poverty for all peo...
# 4  By 2030, eradicate extreme poverty for all peo...
#
#                                       TARGET_DESC_AR INDICATOR_LABEL  \
# 0  القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 1  القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 2  القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 3  القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 4  القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
#
#   INDICATOR_ID                                  INDICATOR_DESC_EN  \
# 0   C010101      Proportion of population below the internatio...
# 1   C010101      Proportion of population below the internatio...
# 2   C010101      Proportion of population below the internatio...
# 3   C010101      Proportion of population below the internatio...
# 4   C010101      Proportion of population below the internatio...
#
#                                    INDICATOR_DESC_AR      ...        \
# 0  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 1  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 2  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 3  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 4  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
#
#   INTERNET_SPEED_DESC_EN INTERNET_SPEED_DESC_AR OBS_VALUE  UNIT_MULT  \
# 0                    NaN                    NaN       NaN        NaN
# 1                    NaN                    NaN       NaN        NaN
# 2                    NaN                    NaN       NaN        NaN
# 3                    NaN                    NaN       NaN        NaN
# 4                    NaN                    NaN       NaN        NaN
#
#    UNIT_MEASURE OBS_STATUS  TIME_DETAIL COMMENT_OBS BASE_PER  SOURCE_DETAIL
# 0           NaN        NaN          NaN         NaN      NaN            NaN
# 1           NaN        NaN          NaN         NaN      NaN            NaN
# 2           NaN        NaN          NaN         NaN      NaN            NaN
# 3           NaN        NaN          NaN         NaN      NaN            NaN
# 4           NaN        NaN          NaN         NaN      NaN            NaN
#
# [5 rows x 76 columns]

# %% [markdown]
# ### 2.2.b Remove `TIME_PERIOD` and keep only unique records
# In order to create a 'master' template for the SDG matrix, remove data from the `TIME PERIOD` column, and keep only unique records, and save this revised template as an excel file.

# %%
sdgMatrix_df['TIME_PERIOD'] = None

sdgMatrix_df = sdgMatrix_df.drop_duplicates()

sdgMatrix_df.to_excel(output_dir + 'sdgMatrix_master.xlsx',index=False, encoding='UTF-8')

# %% [markdown]
# # 3. Read available datasets
#
# PCBS has provided a set of excel files with SDG data that is currently available. First, re-name those files in a systematic way.  After that, clean up the files to remove hiddent (filetere-out) cells.

# %%
from os import listdir
from os.path import isfile, join

mdt_path = r'../MDT/'
mdt_files = [f for f in listdir(mdt_path) if isfile(join(mdt_path, f))]

# Print first 10 files in the list:
mdt_files[0:9]
# Out:
# ['MDT_01.02.01.xlsx',
#  'MDT_01.05.01.xlsx',
#  'MDT_01.05.02.xlsx',
#  'MDT_01.05.04.xlsx',
#  'MDT_02.01.02.xlsx',
#  'MDT_02.02.01.xlsx',
#  'MDT_03.01.01.xlsx',
#  'MDT_03.01.02.xlsx',
#  'MDT_03.02.01.xlsx']

# %% [markdown]
# A csv file was created based on this list of MDT, assigning to each of them a standardized data frame name:

# %%
import csv

mdt_path = r'../MDT/'

with open(mdt_path + 'mdt_files.csv', encoding='UTF-8') as f:
    mdt_files = [{k: v for k, v in row.items()} for row in csv.DictReader(f)]

# %% [markdown]
# Now it is possible to read each individual MDT file and assign it to a data frame in a list:

# %%
mdt_files
# Out:
# [{'data_frame_name': 'MDT_01.02.01',
#   'file_name': '1.2.1_C010201_MDT template.xlsx'},
#  {'data_frame_name': 'MDT_01.05.01',
#   'file_name': '1.5.1_C010501_MDT template.xlsx'},
#  {'data_frame_name': 'MDT_01.05.02',
#   'file_name': '1.5.2_C010502_MDT template.xlsx'},
#  {'data_frame_name': 'MDT_01.05.04',
#   'file_name': '1.5.4_C010504_MDT template.xlsx'},
#  {'data_frame_name': 'MDT_10.01.01', 'file_name': '10.1.1.xlsx'},
#  {'data_frame_name': 'MDT_10.0c.01', 'file_name': '10.c.1.xlsx'},
#  {'data_frame_name': 'MDT_11.05.01.1', 'file_name': '11.5.1.1SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_11.05.01.2',
#   'file_name': '11.5.1.2 SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_11.05.01.3', 'file_name': '11.5.1.3SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_11.0b.02', 'file_name': '11.b.2SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_12.01.01', 'file_name': '12.1.1SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_12.04.01', 'file_name': '12.4.1SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_13.01.01.1',
#   'file_name': '13.1.1.1 SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_13.01.01.2',
#   'file_name': '13.1.1.2 SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_13.01.01.3',
#   'file_name': '13.1.1.3 SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_15.01.01', 'file_name': '15.1.1SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_15.01.02', 'file_name': '15.1.2SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_15.04.01', 'file_name': '15.4.1SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_15.04.02', 'file_name': '15.4.2SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_15.05.01', 'file_name': '15.5.1SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_15.0a.01', 'file_name': '15.a.1SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_15.0b.01', 'file_name': '15.b.1SDGsMatrix.xlsx'},
#  {'data_frame_name': 'MDT_16.01.01', 'file_name': '16.1.1.xlsx'},
#  {'data_frame_name': 'MDT_16.01.04', 'file_name': '16.1.4.xlsx'},
#  {'data_frame_name': 'MDT_16.02.01', 'file_name': '16.2.1.xlsx'},
#  {'data_frame_name': 'MDT_16.03.01', 'file_name': '16.3.1.xlsx'},
#  {'data_frame_name': 'MDT_16.03.02', 'file_name': '16.3.2.xlsx'},
#  {'data_frame_name': 'MDT_16.05.01', 'file_name': '16.5.1.xlsx'},
#  {'data_frame_name': 'MDT_16.06.02_1', 'file_name': '16.6.2_1.xlsx'},
#  {'data_frame_name': 'MDT_16.06.02_2', 'file_name': '16.6.2_2.xlsx'},
#  {'data_frame_name': 'MDT_16.06.02_3', 'file_name': '16.6.2_3.xlsx'},
#  {'data_frame_name': 'MDT_16.06.02_4', 'file_name': '16.6.2_4.xlsx'},
#  {'data_frame_name': 'MDT_16.07.02_1', 'file_name': '16.7.2_1.xlsx'},
#  {'data_frame_name': 'MDT_16.07.02_2', 'file_name': '16.7.2_2.xlsx'},
#  {'data_frame_name': 'MDT_16.09.01_1', 'file_name': '16.9.1_1.xlsx'},
#  {'data_frame_name': 'MDT_16.09.01_2', 'file_name': '16.9.1_2.xlsx'},
#  {'data_frame_name': 'MDT_16.09.01_3', 'file_name': '16.9.1_3.xlsx'},
#  {'data_frame_name': 'MDT_16.09.01_4', 'file_name': '16.9.1_4.xlsx'},
#  {'data_frame_name': 'MDT_16.09.01_5', 'file_name': '16.9.1_5.xlsx'},
#  {'data_frame_name': 'MDT_16.0b.01', 'file_name': '16.b.1.xlsx'},
#  {'data_frame_name': 'MDT_17.01.01', 'file_name': '17.1.1.xlsx'},
#  {'data_frame_name': 'MDT_17.01.02', 'file_name': '17.1.2.xlsx'},
#  {'data_frame_name': 'MDT_17.18.03', 'file_name': '17.18.3.xlsx'},
#  {'data_frame_name': 'MDT_17.19.02_2', 'file_name': '17.19.2_2.xlsx'},
#  {'data_frame_name': 'MDT_17.19.02_3', 'file_name': '17.19.2_3.xlsx'},
#  {'data_frame_name': 'MDT_17.03.01', 'file_name': '17.3.1.xlsx'},
#  {'data_frame_name': 'MDT_17.03.02', 'file_name': '17.3.2.xlsx'},
#  {'data_frame_name': 'MDT_17.06.02_1', 'file_name': '17.6.2_1.xlsx'},
#  {'data_frame_name': 'MDT_17.06.02_2', 'file_name': '17.6.2_2.xlsx'},
#  {'data_frame_name': 'MDT_17.06.02_3', 'file_name': '17.6.2_3.xlsx'},
#  {'data_frame_name': 'MDT_17.08.01', 'file_name': '17.8.1.xlsx'},
#  {'data_frame_name': 'MDT_02.01.02',
#   'file_name': '2.1.2_C020102_MDT template.xlsx'},
#  {'data_frame_name': 'MDT_02.02.01',
#   'file_name': '2.2.1_C020201_MDT template.xlsx'},
#  {'data_frame_name': 'MDT_05.02.01',
#   'file_name': '5.2.1_C050201_MDT template.xlsx'},
#  {'data_frame_name': 'MDT_05.02.02',
#   'file_name': '5.2.2_C050202_MDT template.xlsx'},
#  {'data_frame_name': 'MDT_05.03.01',
#   'file_name': '5.3.1_C050301_MDT template.xlsx'},
#  {'data_frame_name': 'MDT_05.04.01',
#   'file_name': '5.4.1_C050401_MDT template.xlsx'},
#  {'data_frame_name': 'MDT_05.05.01',
#   'file_name': '5.5.1_C050501_MDT template.xlsx'},
#  {'data_frame_name': 'MDT_05.05.02',
#   'file_name': '5.5.2_C050502_MDT template.xlsx'},
#  {'data_frame_name': 'MDT_05.0b.01',
#   'file_name': '5.b.1_C050b01_MDT template.xlsx'},
#  {'data_frame_name': 'MDT_06.01.01', 'file_name': '6.1.1 multi.xlsx'},
#  {'data_frame_name': 'MDT_06.02.01', 'file_name': '6.2.1 multi.xlsx'},
#  {'data_frame_name': 'MDT_07.01.01', 'file_name': '7.1.1 mulit.xlsx'},
#  {'data_frame_name': 'MDT_07.01.02', 'file_name': '7.1.2 multi.xlsx'},
#  {'data_frame_name': 'MDT_08.01.01', 'file_name': '8.1.1M.xlsx'},
#  {'data_frame_name': 'MDT_08.10.01', 'file_name': '8.10.1M.xlsx'},
#  {'data_frame_name': 'MDT_08.10.02', 'file_name': '8.10.2M.xlsx'},
#  {'data_frame_name': 'MDT_08.02.01', 'file_name': '8.2.1M.xlsx'},
#  {'data_frame_name': 'MDT_08.03.01', 'file_name': '8.3.1M.xlsx'},
#  {'data_frame_name': 'MDT_08.05.01', 'file_name': '8.5.1M.xlsx'},
#  {'data_frame_name': 'MDT_08.05.02', 'file_name': '8.5.2M.xlsx'},
#  {'data_frame_name': 'MDT_08.06.01', 'file_name': '8.6.1M.xlsx'},
#  {'data_frame_name': 'MDT_08.07.01', 'file_name': '8.7.1M.xlsx'},
#  {'data_frame_name': 'MDT_08.09.01', 'file_name': '8.9.1M.xlsx'},
#  {'data_frame_name': 'MDT_08.09.02', 'file_name': '8.9.2M.xlsx'},
#  {'data_frame_name': 'MDT_08.0a.01', 'file_name': '8.a.1M.xlsx'},
#  {'data_frame_name': 'MDT_09.02.01', 'file_name': '9.2.1M.xlsx'},
#  {'data_frame_name': 'MDT_09.02.02', 'file_name': '9.2.2M.xlsx'},
#  {'data_frame_name': 'MDT_09.03.01', 'file_name': '9.3.1M.xlsx'},
#  {'data_frame_name': 'MDT_09.04.01', 'file_name': '9.4.1M.xlsx'},
#  {'data_frame_name': 'MDT_09.05.01', 'file_name': '9.5.1M.xlsx'},
#  {'data_frame_name': 'MDT_09.05.02', 'file_name': '9.5.2M.xlsx'},
#  {'data_frame_name': 'MDT_09.0b.01', 'file_name': '9.b.1M.xlsx'},
#  {'data_frame_name': 'MDT_09.0c.01', 'file_name': '9.c.1M.xlsx'},
#  {'data_frame_name': 'MDT_03.01.01',
#   'file_name': 'Subindicator_C030101_01_template.xlsx'},
#  {'data_frame_name': 'MDT_03.01.02',
#   'file_name': 'Subindicator_C030102_01_template.xlsx'},
#  {'data_frame_name': 'MDT_03.02.01',
#   'file_name': 'Subindicator_C030201_01_template.xlsx'},
#  {'data_frame_name': 'MDT_03.02.02',
#   'file_name': 'Subindicator_C030202_01_template.xlsx'},
#  {'data_frame_name': 'MDT_03.03.01',
#   'file_name': 'Subindicator_C030301_01_template.xlsx'},
#  {'data_frame_name': 'MDT_03.03.02',
#   'file_name': 'Subindicator_C030302_01_template.xlsx'},
#  {'data_frame_name': 'MDT_03.03.03',
#   'file_name': 'Subindicator_C030303_01_template.xlsx'},
#  {'data_frame_name': 'MDT_03.03.04',
#   'file_name': 'Subindicator_C030304_01_template.xlsx'},
#  {'data_frame_name': 'MDT_03.04.01',
#   'file_name': 'Subindicator_C030401_01_template.xlsx'},
#  {'data_frame_name': 'MDT_03.07.01',
#   'file_name': 'Subindicator_C030701_01_template.xlsx'},
#  {'data_frame_name': 'MDT_03.07.02',
#   'file_name': 'Subindicator_C030702_01_template.xlsx'},
#  {'data_frame_name': 'MDT_03.0a.01',
#   'file_name': 'Subindicator_C030a01_01_template.xlsx'},
#  {'data_frame_name': 'MDT_04.02.02',
#   'file_name': 'Subindicator_C040202_01_template (1).xlsx'},
#  {'data_frame_name': 'MDT_04.03.01',
#   'file_name': 'Subindicator_C040301_01_template.xlsx'},
#  {'data_frame_name': 'MDT_04.04.01',
#   'file_name': 'Subindicator_C040401_01_template.xlsx'},
#  {'data_frame_name': 'MDT_04.0a.01',
#   'file_name': 'Subindicator_C040a01_01_template.xlsx'},
#  {'data_frame_name': 'MDT_04.0c.01',
#   'file_name': 'Subindicator_C040c01_01_template.xlsx'}]

# %% [markdown]
# The following code cell reads the contents of each file, skipping any filtered out rows, and saves the data in a new file under 'output' folder.

# %%
from openpyxl import load_workbook

for mdt in mdt_files:
    print(mdt['data_frame_name'])
    wb = load_workbook(mdt_path+mdt['data_frame_name']+'.xlsx') # use the actual path of your workbook
    ws = wb.worksheets[0]

    row_count = 0
    data = []
    columns = []
    for row in ws:
        record = {}
        # use the row only if it has not been filtered out (i.e., it's not hidden)
        nonempty_row = False
        if ws.row_dimensions[row[0].row].hidden == False:
            for cell in row:
                if cell.value != None: 
                    row_count += 1
                    #print(row_count)
                    break
            if row_count == 1:
                #print('row_count='+str(row_count))
                for cell in row:
                    columns.append(cell.value)
                #print('number_of_columns=', str(len(columns)))
               # print(columns)
            if row_count > 1:
                cell_count = 0
                #print('dataRow_count='+str(row_count))
                for cell in row:
                    #print(columns[cell_count] + '=' + str(cell.value))
                    record[columns[cell_count]] = cell.value
                    cell_count += 1
                data.append(record)

    pd.DataFrame(data).to_excel(output_dir + 'clean_' + mdt['data_frame_name']+'.xlsx',index=False, encoding='UTF-8')

# %% [markdown]
# # 4. Consolidate the data into a single matrix

# %% [markdown]
# ## 4.1 Identify the columns available for each file

# %%
with open(mdt_path + 'mdt_columns_mapping.csv') as f:
    column_mapping = [{k: v for k, v in row.items()}
                      for row in csv.DictReader(f, skipinitialspace=True)]
column_mapping
# Out:
# [{'New_Name': 'GOAL', 'Old_Name': 'Goal_ID', 'Role': 'Reference'},
#  {'New_Name': 'GOAL_DESC_AR', 'Old_Name': 'Goal_DescAr', 'Role': 'Reference'},
#  {'New_Name': 'GOAL_DESC_EN', 'Old_Name': 'Goal_DescEn', 'Role': 'Reference'},
#  {'New_Name': 'TARGET', 'Old_Name': 'Target_ID', 'Role': 'Reference'},
#  {'New_Name': 'TARGET_DESC_AR',
#   'Old_Name': 'Target_DescAr',
#   'Role': 'Reference'},
#  {'New_Name': 'TARGET_DESC_EN',
#   'Old_Name': 'Target_DescEn',
#   'Role': 'Reference'},
#  {'New_Name': 'INDICATOR', 'Old_Name': 'Indicator_NL', 'Role': 'Reference'},
#  {'New_Name': 'INDICATOR_CODE',
#   'Old_Name': 'Indicator_Code',
#   'Role': 'Reference'},
#  {'New_Name': 'INDICATOR_CODE_DESC_AR',
#   'Old_Name': 'Indicator_descAr',
#   'Role': 'Reference'},
#  {'New_Name': 'INDICATOR_CODE_DESC_EN',
#   'Old_Name': 'Indicator_descEn',
#   'Role': 'Reference'},
#  {'New_Name': 'SUBINDICATOR_CODE',
#   'Old_Name': 'Subindicator_Code',
#   'Role': 'Reference'},
#  {'New_Name': 'SUBINDICATOR_CODE_DESC_AR',
#   'Old_Name': 'Subindicator_DescAr',
#   'Role': 'Reference'},
#  {'New_Name': 'SUBINDICATOR_CODE_DESC_EN',
#   'Old_Name': 'Subindicator_DescEn',
#   'Role': 'Reference'},
#  {'New_Name': '_NOT_DEFINED_1', 'Old_Name': 'Colonna1', 'Role': 'Dimension'},
#  {'New_Name': '_NOT_DEFINED_2', 'Old_Name': 'Column1', 'Role': 'Dimension'},
#  {'New_Name': '_NOT_DEFINED_3',
#   'Old_Name': 'Unnamed: 24',
#   'Role': 'Dimension'},
#  {'New_Name': '_NOT_DEFINED_4',
#   'Old_Name': 'Unnamed: 76',
#   'Role': 'Dimension'},
#  {'New_Name': 'AGE', 'Old_Name': 'AGE', 'Role': 'Dimension'},
#  {'New_Name': 'AGE', 'Old_Name': 'Age', 'Role': 'Dimension'},
#  {'New_Name': 'AGE_DESC_AR', 'Old_Name': 'Age_DescAr', 'Role': 'Dimension'},
#  {'New_Name': 'AGE_DESC_EN', 'Old_Name': 'Age_DescEn', 'Role': 'Dimension'},
#  {'New_Name': 'DISABILITY_STATUS',
#   'Old_Name': 'DISABILITY_STATUS',
#   'Role': 'Dimension'},
#  {'New_Name': 'DISABILITY_STATUS_DESC_AR',
#   'Old_Name': 'DisabilityStatus_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'DISABILITY_STATUS_DESC_EN',
#   'Old_Name': 'DisabilityStatus_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'ECOSYSTEM_TYPE',
#   'Old_Name': 'EcosystemType',
#   'Role': 'Dimension'},
#  {'New_Name': 'ECOSYSTEM_TYPE_DESC_AR',
#   'Old_Name': 'EcosystemType_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'ECOSYSTEM_TYPE_DESC_EN',
#   'Old_Name': 'EcosystemType_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'EDUCATION_LEVEL',
#   'Old_Name': 'EDUCATION_LEV',
#   'Role': 'Dimension'},
#  {'New_Name': 'EDUCATION_LEVEL',
#   'Old_Name': 'Level of Education',
#   'Role': 'Dimension'},
#  {'New_Name': 'EDUCATION_LEVEL_DESC_AR',
#   'Old_Name': 'Education_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'EDUCATION_LEVEL_DESC_EN',
#   'Old_Name': 'Education_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'EMPLOYMENT_STATUS',
#   'Old_Name': 'EmploymentStatus',
#   'Role': 'Dimension'},
#  {'New_Name': 'EMPLOYMENT_STATUS_DESC_AR',
#   'Old_Name': 'EmploymentStatus_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'EMPLOYMENT_STATUS_DESC_EN',
#   'Old_Name': 'EmploymentStatus_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'INTERNET_SPEED',
#   'Old_Name': 'InternetSpeed',
#   'Role': 'Dimension'},
#  {'New_Name': 'INTERNET_SPEED_DESC_AR',
#   'Old_Name': 'InternetSpeed_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'INTERNET_SPEED_DESC_EN',
#   'Old_Name': 'InternetSpeed_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'MOBILE_NETWORK_TECHNOLOGY',
#   'Old_Name': 'MobileNetworkTechnology',
#   'Role': 'Dimension'},
#  {'New_Name': 'MOBILE_NETWORK_TECHNOLOGY_DESC_AR',
#   'Old_Name': 'MobileNetworkTechnology_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'MOBILE_NETWORK_TECHNOLOGY_DESC_EN',
#   'Old_Name': 'MobileNetworkTechnology_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'OCCUPATION', 'Old_Name': 'OCCUPATION', 'Role': 'Dimension'},
#  {'New_Name': 'OCCUPATION_DESC_AR',
#   'Old_Name': 'Occupation_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'OCCUPATION_DESC_EN',
#   'Old_Name': 'Occupation_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'POVERTY_STATUS',
#   'Old_Name': 'PovertyStatus',
#   'Role': 'Dimension'},
#  {'New_Name': 'POVERTY_STATUS_DESC_AR',
#   'Old_Name': 'PovertyStatus_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'POVERTY_STATUS_DESC_EN',
#   'Old_Name': 'PovertyStatus_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'PREGNANCY_STATUS',
#   'Old_Name': 'PregnancyStatus',
#   'Role': 'Dimension'},
#  {'New_Name': 'PREGNANCY_STATUS_DESC_AR',
#   'Old_Name': 'PregnancyStatus_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'PREGNANCY_STATUS_DESC_EN',
#   'Old_Name': 'PregnancyStatus_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'SCHOOLING_YEARS',
#   'Old_Name': 'YearsOfSchooling',
#   'Role': 'Dimension'},
#  {'New_Name': 'SCHOOLING_YEARS',
#   'Old_Name': 'years-schooling',
#   'Role': 'Dimension'},
#  {'New_Name': 'SCHOOLING_YEARS_DESC_AR',
#   'Old_Name': 'YearsOfSchooling_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'SCHOOLING_YEARS_DESC_EN',
#   'Old_Name': 'YearsOfSchooling_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'SECTOR', 'Old_Name': 'Sector', 'Role': 'Dimension'},
#  {'New_Name': 'SECTOR_DESC_AR',
#   'Old_Name': 'Sector_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'SECTOR_DESC_EN',
#   'Old_Name': 'Sector_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'SEX', 'Old_Name': 'SEX', 'Role': 'Dimension'},
#  {'New_Name': 'SEX_DESC_AR', 'Old_Name': 'SEX_DESC_AR', 'Role': 'Dimension'},
#  {'New_Name': 'SEX_DESC_EN', 'Old_Name': 'SEX_DESC_EN', 'Role': 'Dimension'},
#  {'New_Name': 'STUDY_AREA', 'Old_Name': 'AreaOfStudy', 'Role': 'Dimension'},
#  {'New_Name': 'STUDY_AREA_DESC_AR',
#   'Old_Name': 'AreaOfStudy_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'STUDY_AREA_DESC_EN',
#   'Old_Name': 'AreaOfStudy_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'URBANISATION', 'Old_Name': 'URBANISATION', 'Role': 'Dimension'},
#  {'New_Name': 'URBANISATION_DESC_AR',
#   'Old_Name': 'Urbanisation_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'URBANISATION_DESC_EN',
#   'Old_Name': 'Urbanisation_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'VIOLENCE_TYPE',
#   'Old_Name': 'TypeOfViolence',
#   'Role': 'Dimension'},
#  {'New_Name': 'VIOLENCE_TYPE_DESC_AR',
#   'Old_Name': 'TypeOfViolence_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'VIOLENCE_TYPE_DESC_EN',
#   'Old_Name': 'TypeOfViolence_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'WORKING_INJURY_STATUS',
#   'Old_Name': 'WorkingInjuryStatus',
#   'Role': 'Dimension'},
#  {'New_Name': 'WORKING_INJURY_STATUS_DESC_AR',
#   'Old_Name': 'WorkingInjuryStatus_DescAr',
#   'Role': 'Dimension'},
#  {'New_Name': 'WORKING_INJURY_STATUS_DESC_EN',
#   'Old_Name': 'WorkingInjuryStatus_DescEn',
#   'Role': 'Dimension'},
#  {'New_Name': 'REF_AREA', 'Old_Name': 'REF_AREA', 'Role': 'Geo'},
#  {'New_Name': 'REF_AREA_DESC_AR',
#   'Old_Name': 'REF_AREA_DESC_AR',
#   'Role': 'Geo'},
#  {'New_Name': 'REF_AREA_DESC_EN',
#   'Old_Name': 'REF_AREA_DESC_EN',
#   'Role': 'Geo'},
#  {'New_Name': 'TIME_PERIOD', 'Old_Name': 'TIME_PERIOD', 'Role': 'Time'},
#  {'New_Name': 'OBS_COMMENT', 'Old_Name': 'COMMENT_OBS', 'Role': 'Observation'},
#  {'New_Name': 'OBS_STATUS', 'Old_Name': 'OBS_STATUS', 'Role': 'Observation'},
#  {'New_Name': 'OBS_VALUE', 'Old_Name': 'OBS_VALUE', 'Role': 'Observation'},
#  {'New_Name': 'UNIT_MEASURE', 'Old_Name': 'UNIT_MEASURE', 'Role': 'Attribute'},
#  {'New_Name': 'UNIT_MULT', 'Old_Name': 'UNIT_MULT', 'Role': 'Attribute'},
#  {'New_Name': 'BASE_PERIOD', 'Old_Name': 'BASE_PER', 'Role': 'Attribute'},
#  {'New_Name': 'TIME_DETAIL', 'Old_Name': 'TIME_DETAIL', 'Role': 'Attribute'},
#  {'New_Name': 'SOURCE_DETAIL',
#   'Old_Name': 'SOURCE_DETAIL',
#   'Role': 'Attribute'},
#  {'New_Name': 'SOURCE_DETAIL_DESC_AR',
#   'Old_Name': 'SOURCE_DETAIL_AR',
#   'Role': 'Attribute'},
#  {'New_Name': 'SOURCE_DETAIL_DESC_EN',
#   'Old_Name': 'SOURCE_DETAIL_Ar',
#   'Role': 'Attribute'}]

# %%
consolidated_mdt = []

for mdt in mdt_files:
    print('reading ' + output_dir + 'clean_' + mdt['data_frame_name']+'.xlsx')
    df = pd.read_excel(output_dir + 'clean_' + mdt['data_frame_name']+'.xlsx', encoding='UTF-8')
    for r in column_mapping:
        if r['Old_Name'] in df.columns:
            df = df.rename(columns={r['Old_Name'] : r['New_Name']})
    #print(df.columns)
    # store DataFrame in list
    consolidated_mdt.append(df)
# Out:
# reading ../SDG-Matrix/Output/clean_MDT_01.02.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_01.05.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_01.05.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_01.05.04.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_10.01.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_10.0c.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_11.05.01.1.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_11.05.01.2.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_11.05.01.3.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_11.0b.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_12.01.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_12.04.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_13.01.01.1.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_13.01.01.2.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_13.01.01.3.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_15.01.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_15.01.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_15.04.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_15.04.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_15.05.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_15.0a.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_15.0b.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.01.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.01.04.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.02.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.03.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.03.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.05.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.06.02_1.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.06.02_2.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.06.02_3.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.06.02_4.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.07.02_1.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.07.02_2.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.09.01_1.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.09.01_2.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.09.01_3.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.09.01_4.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.09.01_5.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_16.0b.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_17.01.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_17.01.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_17.18.03.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_17.19.02_2.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_17.19.02_3.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_17.03.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_17.03.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_17.06.02_1.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_17.06.02_2.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_17.06.02_3.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_17.08.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_02.01.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_02.02.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_05.02.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_05.02.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_05.03.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_05.04.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_05.05.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_05.05.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_05.0b.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_06.01.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_06.02.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_07.01.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_07.01.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_08.01.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_08.10.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_08.10.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_08.02.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_08.03.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_08.05.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_08.05.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_08.06.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_08.07.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_08.09.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_08.09.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_08.0a.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_09.02.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_09.02.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_09.03.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_09.04.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_09.05.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_09.05.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_09.0b.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_09.0c.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_03.01.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_03.01.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_03.02.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_03.02.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_03.03.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_03.03.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_03.03.03.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_03.03.04.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_03.04.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_03.07.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_03.07.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_03.0a.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_04.02.02.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_04.03.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_04.04.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_04.0a.01.xlsx
# reading ../SDG-Matrix/Output/clean_MDT_04.0c.01.xlsx

# %%
consolidated_mdt[0]
# Out:
#    BASE_PERIOD                                        OBS_COMMENT  \
# 0            ?  The data represent households and not populati...
# 1          NaN  The data represent households and not populati...
# 2          NaN  The data represent households and not populati...
# 3          NaN  The data represent households and not populati...
# 4          NaN  The data represent households and not populati...
# 5          NaN  The data represent households and not populati...
# 6          NaN  The data represent households and not populati...
# 7          NaN  The data represent households and not populati...
# 8          NaN  The data represent households and not populati...
# 9          NaN  The data represent households and not populati...
# 10         NaN  The data represent households and not populati...
# 11         NaN  The data represent households and not populati...
# 12         NaN  The data represent households and not populati...
# 13         NaN  The data represent households and not populati...
# 14         NaN  The data represent households and not populati...
# 15         NaN  The data represent households and not populati...
# 16         NaN  The data represent households and not populati...
# 17         NaN  The data represent households and not populati...
# 18         NaN  The data represent households and not populati...
# 19         NaN  The data represent households and not populati...
# 20         NaN  The data represent households and not populati...
#
#     GOAL_DESC_AR GOAL_DESC_EN  GOAL INDICATOR_CODE  INDICATOR  \
# 0            NaN       Goal 1     1        C010201        NaN
# 1            NaN          NaN     1        C010201        NaN
# 2            NaN          NaN     1        C010201        NaN
# 3            NaN          NaN     1        C010201        NaN
# 4            NaN          NaN     1        C010201        NaN
# 5            NaN          NaN     1        C010201        NaN
# 6            NaN          NaN     1        C010201        NaN
# 7            NaN          NaN     1        C010201        NaN
# 8            NaN          NaN     1        C010201        NaN
# 9            NaN          NaN     1        C010201        NaN
# 10           NaN          NaN     1        C010201        NaN
# 11           NaN          NaN     1        C010201        NaN
# 12           NaN          NaN     1        C010201        NaN
# 13           NaN          NaN     1        C010201        NaN
# 14           NaN          NaN     1        C010201        NaN
# 15           NaN          NaN     1        C010201        NaN
# 16           NaN          NaN     1        C010201        NaN
# 17           NaN          NaN     1        C010201        NaN
# 18           NaN          NaN     1        C010201        NaN
# 19           NaN          NaN     1        C010201        NaN
# 20           NaN          NaN     1        C010201        NaN
#
#                                INDICATOR_CODE_DESC_AR  \
# 0     نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 1     نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 2     نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 3     نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 4     نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 5     نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 6     نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 7     نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 8     نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 9     نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 10    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 11    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 12    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 13    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 14    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 15    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 16    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 17    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 18    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 19    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 20    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
#
#                                INDICATOR_CODE_DESC_EN OBS_STATUS    ...      \
# 0   Proportion of population living below the nati...          ?    ...
# 1   Proportion of population living below the nati...        NaN    ...
# 2   Proportion of population living below the nati...        NaN    ...
# 3   Proportion of population living below the nati...        NaN    ...
# 4   Proportion of population living below the nati...        NaN    ...
# 5   Proportion of population living below the nati...        NaN    ...
# 6   Proportion of population living below the nati...        NaN    ...
# 7   Proportion of population living below the nati...        NaN    ...
# 8   Proportion of population living below the nati...        NaN    ...
# 9   Proportion of population living below the nati...        NaN    ...
# 10  Proportion of population living below the nati...        NaN    ...
# 11  Proportion of population living below the nati...        NaN    ...
# 12  Proportion of population living below the nati...        NaN    ...
# 13  Proportion of population living below the nati...        NaN    ...
# 14  Proportion of population living below the nati...        NaN    ...
# 15  Proportion of population living below the nati...        NaN    ...
# 16  Proportion of population living below the nati...        NaN    ...
# 17  Proportion of population living below the nati...        NaN    ...
# 18  Proportion of population living below the nati...        NaN    ...
# 19  Proportion of population living below the nati...        NaN    ...
# 20  Proportion of population living below the nati...        NaN    ...
#
#     SUBINDICATOR_CODE SUBINDICATOR_CODE_DESC_AR SUBINDICATOR_CODE_DESC_EN  \
# 0          C010201_01                       NaN                       NaN
# 1          C010201_01                       NaN                       NaN
# 2          C010201_01                       NaN                       NaN
# 3          C010201_01                       NaN                       NaN
# 4          C010201_01                       NaN                       NaN
# 5          C010201_01                       NaN                       NaN
# 6          C010201_01                       NaN                       NaN
# 7          C010201_01                       NaN                       NaN
# 8          C010201_01                       NaN                       NaN
# 9          C010201_01                       NaN                       NaN
# 10         C010201_01                       NaN                       NaN
# 11         C010201_01                       NaN                       NaN
# 12         C010201_01                       NaN                       NaN
# 13         C010201_01                       NaN                       NaN
# 14         C010201_01                       NaN                       NaN
# 15         C010201_01                       NaN                       NaN
# 16         C010201_01                       NaN                       NaN
# 17         C010201_01                       NaN                       NaN
# 18         C010201_01                       NaN                       NaN
# 19         C010201_01                       NaN                       NaN
# 20         C010201_01                       NaN                       NaN
#
#    TIME_DETAIL TIME_PERIOD  TARGET_DESC_AR  TARGET_DESC_EN TARGET  \
# 0            ?      2009.0             NaN             NaN    1.0
# 1          NaN      2010.0             NaN             NaN    NaN
# 2          NaN      2011.0             NaN             NaN    NaN
# 3          NaN      2017.0             NaN             NaN    NaN
# 4          NaN      2009.0             NaN             NaN    NaN
# 5          NaN      2010.0             NaN             NaN    NaN
# 6          NaN      2011.0             NaN             NaN    NaN
# 7          NaN      2017.0             NaN             NaN    NaN
# 8          NaN      2009.0             NaN             NaN    NaN
# 9          NaN      2010.0             NaN             NaN    NaN
# 10         NaN      2011.0             NaN             NaN    NaN
# 11         NaN      2017.0             NaN             NaN    NaN
# 12         NaN      2009.0             NaN             NaN    NaN
# 13         NaN      2010.0             NaN             NaN    NaN
# 14         NaN      2011.0             NaN             NaN    NaN
# 15         NaN      2017.0             NaN             NaN    NaN
# 16         NaN      2009.0             NaN             NaN    NaN
# 17         NaN      2010.0             NaN             NaN    NaN
# 18         NaN      2011.0             NaN             NaN    NaN
# 19         NaN      2017.0             NaN             NaN    NaN
# 20         NaN         NaN             NaN             NaN    NaN
#
#     UNIT_MEASURE  UNIT_MULT
# 0              %          ?
# 1              %        NaN
# 2              %        NaN
# 3              %        NaN
# 4              %        NaN
# 5              %        NaN
# 6              %        NaN
# 7              %        NaN
# 8              %        NaN
# 9              %        NaN
# 10             %        NaN
# 11             %        NaN
# 12             %        NaN
# 13             %        NaN
# 14             %        NaN
# 15             %        NaN
# 16             %        NaN
# 17             %        NaN
# 18             %        NaN
# 19             %        NaN
# 20           NaN        NaN
#
# [21 rows x 24 columns]

# %%
consolidated_mdt[1]
# Out:
#     BASE_PERIOD  OBS_COMMENT                           _NOT_DEFINED_1  \
# 0           NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 1           NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 2           NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 3           NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 4           NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 5           NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 6           NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 7           NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 8           NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 9           NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 10          NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 11          NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 12          NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 13          NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 14          NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 15          NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 16          NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 17          NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 18          NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 19          NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
# 20          NaN          NaN  المركز الوطني للحد من الكوارث الطبيعية
#
#     GOAL_DESC_AR GOAL_DESC_EN  GOAL INDICATOR_CODE  INDICATOR  \
# 0            NaN       Goal 1     1        C010501        NaN
# 1            NaN       Goal 1     1        C010501        NaN
# 2            NaN       Goal 1     1        C010501        NaN
# 3            NaN       Goal 1     1        C010501        NaN
# 4            NaN       Goal 1     1        C010501        NaN
# 5            NaN       Goal 1     1        C010501        NaN
# 6            NaN       Goal 1     1        C010501        NaN
# 7            NaN       Goal 1     1        C010501        NaN
# 8            NaN       Goal 1     1        C010501        NaN
# 9            NaN       Goal 1     1        C010501        NaN
# 10           NaN       Goal 1     1        C010501        NaN
# 11           NaN       Goal 1     1        C010501        NaN
# 12           NaN       Goal 1     1        C010501        NaN
# 13           NaN       Goal 1     1        C010501        NaN
# 14           NaN       Goal 1     1        C010501        NaN
# 15           NaN       Goal 1     1        C010501        NaN
# 16           NaN       Goal 1     1        C010501        NaN
# 17           NaN       Goal 1     1        C010501        NaN
# 18           NaN       Goal 1     1        C010501        NaN
# 19           NaN       Goal 1     1        C010501        NaN
# 20           NaN       Goal 1     1        C010501        NaN
#
#     INDICATOR_CODE_DESC_AR                             INDICATOR_CODE_DESC_EN  \
# 0                      NaN  1.5.1 Number of deaths, missing persons,  dire...
# 1                      NaN  1.5.1 Number of deaths, missing persons,  dire...
# 2                      NaN  1.5.1 Number of deaths, missing persons,  dire...
# 3                      NaN  1.5.1 Number of deaths, missing persons,  dire...
# 4                      NaN  1.5.1 Number of deaths, missing persons,  dire...
# 5                      NaN  1.5.1 Number of deaths, missing persons,  dire...
# 6                      NaN  1.5.1 Number of deaths, missing persons,  dire...
# 7                      NaN  1.5.1 Number of deaths, missing persons,  dire...
# 8                      NaN  1.5.1 Number of deaths, missing persons,  dire...
# 9                      NaN  1.5.1 Number of deaths, missing persons,  dire...
# 10                     NaN  1.5.1 Number of deaths, missing persons,  dire...
# 11                     NaN  1.5.1 Number of deaths, missing persons,  dire...
# 12                     NaN  1.5.1 Number of deaths, missing persons,  dire...
# 13                     NaN  1.5.1 Number of deaths, missing persons,  dire...
# 14                     NaN  1.5.1 Number of deaths, missing persons,  dire...
# 15                     NaN  1.5.1 Number of deaths, missing persons,  dire...
# 16                     NaN  1.5.1 Number of deaths, missing persons,  dire...
# 17                     NaN  1.5.1 Number of deaths, missing persons,  dire...
# 18                     NaN  1.5.1 Number of deaths, missing persons,  dire...
# 19                     NaN  1.5.1 Number of deaths, missing persons,  dire...
# 20                     NaN  1.5.1 Number of deaths, missing persons,  dire...
#
#       ...      SUBINDICATOR_CODE  \
# 0     ...             C010501_01
# 1     ...             C010501_01
# 2     ...             C010501_01
# 3     ...             C010501_01
# 4     ...             C010501_01
# 5     ...             C010501_01
# 6     ...             C010501_02
# 7     ...             C010501_02
# 8     ...             C010501_02
# 9     ...             C010501_02
# 10    ...             C010501_02
# 11    ...             C010501_02
# 12    ...             C010501_03
# 13    ...             C010501_03
# 14    ...             C010501_03
# 15    ...             C010501_03
# 16    ...             C010501_03
# 17    ...             C010501_03
# 18    ...             C010501_03
# 19    ...             C010501_03
# 20    ...             C010501_03
#
#                           SUBINDICATOR_CODE_DESC_AR  \
# 0      عدد الوفيات  بسبب\nالكوارث من كل 000 100 شخص
# 1      عدد الوفيات  بسبب\nالكوارث من كل 000 100 شخص
# 2      عدد الوفيات  بسبب\nالكوارث من كل 000 100 شخص
# 3      عدد الوفيات  بسبب\nالكوارث من كل 000 100 شخص
# 4      عدد الوفيات  بسبب\nالكوارث من كل 000 100 شخص
# 5      عدد الوفيات  بسبب\nالكوارث من كل 000 100 شخص
# 6   عدد  المفقودين  بسبب\nالكوارث من كل 000 100 شخص
# 7   عدد  المفقودين  بسبب\nالكوارث من كل 000 100 شخص
# 8   عدد  المفقودين  بسبب\nالكوارث من كل 000 100 شخص
# 9   عدد  المفقودين  بسبب\nالكوارث من كل 000 100 شخص
# 10  عدد  المفقودين  بسبب\nالكوارث من كل 000 100 شخص
# 11  عدد  المفقودين  بسبب\nالكوارث من كل 000 100 شخص
# 12    عدد المتضررين بسبب\nالكوارث من كل 000 100 شخص
# 13    عدد المتضررين بسبب\nالكوارث من كل 000 100 شخص
# 14    عدد المتضررين بسبب\nالكوارث من كل 000 100 شخص
# 15    عدد المتضررين بسبب\nالكوارث من كل 000 100 شخص
# 16    عدد المتضررين بسبب\nالكوارث من كل 000 100 شخص
# 17    عدد المتضررين بسبب\nالكوارث من كل 000 100 شخص
# 18    عدد المتضررين بسبب\nالكوارث من كل 000 100 شخص
# 19    عدد المتضررين بسبب\nالكوارث من كل 000 100 شخص
# 20    عدد المتضررين بسبب\nالكوارث من كل 000 100 شخص
#
#                             SUBINDICATOR_CODE_DESC_EN  TIME_DETAIL  \
# 0   1.5.1.1 Number of deaths attributed to disaste...          NaN
# 1   1.5.1.1 Number of deaths attributed to disaste...          NaN
# 2   1.5.1.1 Number of deaths attributed to disaste...          NaN
# 3   1.5.1.1 Number of deaths attributed to disaste...          NaN
# 4   1.5.1.1 Number of deaths attributed to disaste...          NaN
# 5   1.5.1.1 Number of deaths attributed to disaste...          NaN
# 6   1.5.1.2 Number of  missing persons  attributed...          NaN
# 7   1.5.1.2 Number of  missing persons  attributed...          NaN
# 8   1.5.1.2 Number of  missing persons  attributed...          NaN
# 9   1.5.1.2 Number of  missing persons  attributed...          NaN
# 10  1.5.1.2 Number of  missing persons  attributed...          NaN
# 11  1.5.1.2 Number of  missing persons  attributed...          NaN
# 12  1.5.1.3 Number of directly affected persons at...          NaN
# 13  1.5.1.3 Number of directly affected persons at...          NaN
# 14  1.5.1.3 Number of directly affected persons at...          NaN
# 15  1.5.1.3 Number of directly affected persons at...          NaN
# 16  1.5.1.3 Number of directly affected persons at...          NaN
# 17  1.5.1.3 Number of directly affected persons at...          NaN
# 18  1.5.1.3 Number of directly affected persons at...          NaN
# 19  1.5.1.3 Number of directly affected persons at...          NaN
# 20  1.5.1.3 Number of directly affected persons at...          NaN
#
#    TIME_PERIOD TARGET_DESC_AR TARGET_DESC_EN TARGET  UNIT_MEASURE  UNIT_MULT
# 0         2006            NaN            NaN    NaN   Per 100,000        NaN
# 1         2007            NaN            NaN    NaN   Per 100,000        NaN
# 2         2008            NaN            NaN    NaN   Per 100,000        NaN
# 3         2009            NaN            NaN    NaN   Per 100,000        NaN
# 4         2010            NaN            NaN    NaN   Per 100,000        NaN
# 5         2013            NaN            NaN    NaN   Per 100,000        NaN
# 6         2006            NaN            NaN    NaN   Per 100,000        NaN
# 7         2007            NaN            NaN    NaN   Per 100,000        NaN
# 8         2008            NaN            NaN    NaN   Per 100,000        NaN
# 9         2009            NaN            NaN    NaN   Per 100,000        NaN
# 10        2010            NaN            NaN    NaN   Per 100,000        NaN
# 11        2013            NaN            NaN    NaN   Per 100,000        NaN
# 12        2005            NaN            NaN    NaN   Per 100,000        NaN
# 13        2006            NaN            NaN    NaN   Per 100,000        NaN
# 14        2007            NaN            NaN    NaN   Per 100,000        NaN
# 15        2008            NaN            NaN    NaN   Per 100,000        NaN
# 16        2009            NaN            NaN    NaN   Per 100,000        NaN
# 17        2010            NaN            NaN    NaN   Per 100,000        NaN
# 18        2011            NaN            NaN    NaN   Per 100,000        NaN
# 19        2012            NaN            NaN    NaN   Per 100,000        NaN
# 20        2013            NaN            NaN    NaN   Per 100,000        NaN
#
# [21 rows x 25 columns]

# %%
x.columns
# Out:
# Index(['BASE_PERIOD', 'OBS_COMMENT', 'GOAL_DESC_AR', 'GOAL_DESC_EN', 'GOAL',
#        'INDICATOR_CODE', 'INDICATOR', 'INDICATOR_CODE_DESC_AR',
#        'INDICATOR_CODE_DESC_EN', 'OBS_STATUS', 'OBS_VALUE', 'REF_AREA', 'SEX',
#        'SOURCE_DETAIL', 'SUBINDICATOR_CODE', 'SUBINDICATOR_CODE_DESC_AR',
#        'SUBINDICATOR_CODE_DESC_EN', 'TIME_DETAIL', 'TIME_PERIOD',
#        'TARGET_DESC_AR', 'TARGET_DESC_EN', 'TARGET', 'UNIT_MEASURE',
#        'UNIT_MULT'],
#       dtype='object')

# %% [markdown]
# **Note:** the mdt file for indicator `MDT_08.05.02` had duplicate columns: `YearsOfSchooling` and `years-schooling`.  One of them was removed (both had no data)

# %%
for i in range(len(consolidated_mdt)-1):
   # print('adding df['+str(i+1)+']')
    x = pd.concat([x,consolidated_mdt[i+1]],axis=0)

# %%
x.head(5)
# Out:
#    AGE  AGE_DESC_AR AGE_DESC_EN BASE_PERIOD  DISABILITY_STATUS  \
# 0  NaN          NaN         NaN           ?                NaN
# 1  NaN          NaN         NaN         NaN                NaN
# 2  NaN          NaN         NaN         NaN                NaN
# 3  NaN          NaN         NaN         NaN                NaN
# 4  NaN          NaN         NaN         NaN                NaN
#
#    DISABILITY_STATUS_DESC_AR  DISABILITY_STATUS_DESC_EN  ECOSYSTEM_TYPE  \
# 0                        NaN                        NaN             NaN
# 1                        NaN                        NaN             NaN
# 2                        NaN                        NaN             NaN
# 3                        NaN                        NaN             NaN
# 4                        NaN                        NaN             NaN
#
#    ECOSYSTEM_TYPE_DESC_AR  ECOSYSTEM_TYPE_DESC_EN      ...        \
# 0                     NaN                     NaN      ...
# 1                     NaN                     NaN      ...
# 2                     NaN                     NaN      ...
# 3                     NaN                     NaN      ...
# 4                     NaN                     NaN      ...
#
#   VIOLENCE_TYPE  VIOLENCE_TYPE_DESC_AR  VIOLENCE_TYPE_DESC_EN  \
# 0           NaN                    NaN                    NaN
# 1           NaN                    NaN                    NaN
# 2           NaN                    NaN                    NaN
# 3           NaN                    NaN                    NaN
# 4           NaN                    NaN                    NaN
#
#    WORKING_INJURY_STATUS  WORKING_INJURY_STATUS_DESC_AR  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN                            NaN
# 4                    NaN                            NaN
#
#    WORKING_INJURY_STATUS_DESC_EN  _NOT_DEFINED_1 _NOT_DEFINED_2  \
# 0                            NaN             NaN            NaN
# 1                            NaN             NaN            NaN
# 2                            NaN             NaN            NaN
# 3                            NaN             NaN            NaN
# 4                            NaN             NaN            NaN
#
#   _NOT_DEFINED_3 _NOT_DEFINED_4
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
#
# [5 rows x 82 columns]

# %%
x.columns
# Out:
# Index(['AGE', 'AGE_DESC_AR', 'AGE_DESC_EN', 'BASE_PERIOD', 'DISABILITY_STATUS',
#        'DISABILITY_STATUS_DESC_AR', 'DISABILITY_STATUS_DESC_EN',
#        'ECOSYSTEM_TYPE', 'ECOSYSTEM_TYPE_DESC_AR', 'ECOSYSTEM_TYPE_DESC_EN',
#        'EDUCATION_LEVEL', 'EDUCATION_LEVEL_DESC_AR', 'EDUCATION_LEVEL_DESC_EN',
#        'EMPLOYMENT_STATUS', 'EMPLOYMENT_STATUS_DESC_AR',
#        'EMPLOYMENT_STATUS_DESC_EN', 'GOAL', 'GOAL_DESC_AR', 'GOAL_DESC_EN',
#        'INDICATOR', 'INDICATOR_CODE', 'INDICATOR_CODE_DESC_AR',
#        'INDICATOR_CODE_DESC_EN', 'INTERNET_SPEED', 'INTERNET_SPEED_DESC_AR',
#        'INTERNET_SPEED_DESC_EN', 'MOBILE_NETWORK_TECHNOLOGY',
#        'MOBILE_NETWORK_TECHNOLOGY_DESC_AR',
#        'MOBILE_NETWORK_TECHNOLOGY_DESC_EN', 'OBS_COMMENT', 'OBS_STATUS',
#        'OBS_VALUE', 'OCCUPATION', 'OCCUPATION_DESC_AR', 'OCCUPATION_DESC_EN',
#        'POVERTY_STATUS', 'POVERTY_STATUS_DESC_AR', 'POVERTY_STATUS_DESC_EN',
#        'PREGNANCY_STATUS', 'PREGNANCY_STATUS_DESC_AR',
#        'PREGNANCY_STATUS_DESC_EN', 'REF_AREA', 'REF_AREA_DESC_AR',
#        'REF_AREA_DESC_EN', 'SCHOOLING_YEARS', 'SCHOOLING_YEARS_DESC_AR',
#        'SCHOOLING_YEARS_DESC_EN', 'SECTOR', 'SECTOR_DESC_AR', 'SECTOR_DESC_EN',
#        'SEX', 'SEX_DESC_AR', 'SEX_DESC_EN', 'SOURCE_DETAIL',
#        'SOURCE_DETAIL_DESC_AR', 'SOURCE_DETAIL_DESC_EN', 'STUDY_AREA',
#        'STUDY_AREA_DESC_AR', 'STUDY_AREA_DESC_EN', 'SUBINDICATOR_CODE',
#        'SUBINDICATOR_CODE_DESC_AR', 'SUBINDICATOR_CODE_DESC_EN', 'TARGET',
#        'TARGET_DESC_AR', 'TARGET_DESC_EN', 'TIME_DETAIL', 'TIME_PERIOD',
#        'UNIT_MEASURE', 'UNIT_MULT', 'URBANISATION', 'URBANISATION_DESC_AR',
#        'URBANISATION_DESC_EN', 'VIOLENCE_TYPE', 'VIOLENCE_TYPE_DESC_AR',
#        'VIOLENCE_TYPE_DESC_EN', 'WORKING_INJURY_STATUS',
#        'WORKING_INJURY_STATUS_DESC_AR', 'WORKING_INJURY_STATUS_DESC_EN',
#        '_NOT_DEFINED_1', '_NOT_DEFINED_2', '_NOT_DEFINED_3', '_NOT_DEFINED_4'],
#       dtype='object')

# %% [markdown]
# #### Re-arrange order of columns:

# %%
 x = x[['GOAL',
'GOAL_DESC_AR',
'GOAL_DESC_EN',
'TARGET',
'TARGET_DESC_AR',
'TARGET_DESC_EN',
'INDICATOR',
'INDICATOR_CODE',
'INDICATOR_CODE_DESC_AR',
'INDICATOR_CODE_DESC_EN',
'SUBINDICATOR_CODE',
'SUBINDICATOR_CODE_DESC_AR',
'SUBINDICATOR_CODE_DESC_EN',
'_NOT_DEFINED_1',
'_NOT_DEFINED_2',
'_NOT_DEFINED_3',
'_NOT_DEFINED_4',
'AGE',
'AGE_DESC_AR',
'AGE_DESC_EN',
'DISABILITY_STATUS',
'DISABILITY_STATUS_DESC_AR',
'DISABILITY_STATUS_DESC_EN',
'ECOSYSTEM_TYPE',
'ECOSYSTEM_TYPE_DESC_AR',
'ECOSYSTEM_TYPE_DESC_EN',
'EDUCATION_LEVEL',
'EDUCATION_LEVEL_DESC_AR',
'EDUCATION_LEVEL_DESC_EN',
'EMPLOYMENT_STATUS',
'EMPLOYMENT_STATUS_DESC_AR',
'EMPLOYMENT_STATUS_DESC_EN',
'INTERNET_SPEED',
'INTERNET_SPEED_DESC_AR',
'INTERNET_SPEED_DESC_EN',
'MOBILE_NETWORK_TECHNOLOGY',
'MOBILE_NETWORK_TECHNOLOGY_DESC_AR',
'MOBILE_NETWORK_TECHNOLOGY_DESC_EN',
'OCCUPATION',
'OCCUPATION_DESC_AR',
'OCCUPATION_DESC_EN',
'POVERTY_STATUS',
'POVERTY_STATUS_DESC_AR',
'POVERTY_STATUS_DESC_EN',
'PREGNANCY_STATUS',
'PREGNANCY_STATUS_DESC_AR',
'PREGNANCY_STATUS_DESC_EN',
'SCHOOLING_YEARS',
'SCHOOLING_YEARS_DESC_AR',
'SCHOOLING_YEARS_DESC_EN',
'SECTOR',
'SECTOR_DESC_AR',
'SECTOR_DESC_EN',
'SEX',
'SEX_DESC_AR',
'SEX_DESC_EN',
'STUDY_AREA',
'STUDY_AREA_DESC_AR',
'STUDY_AREA_DESC_EN',
'URBANISATION',
'URBANISATION_DESC_AR',
'URBANISATION_DESC_EN',
'VIOLENCE_TYPE',
'VIOLENCE_TYPE_DESC_AR',
'VIOLENCE_TYPE_DESC_EN',
'WORKING_INJURY_STATUS',
'WORKING_INJURY_STATUS_DESC_AR',
'WORKING_INJURY_STATUS_DESC_EN',
'REF_AREA',
'REF_AREA_DESC_AR',
'REF_AREA_DESC_EN',
'TIME_PERIOD',
'OBS_COMMENT',
'OBS_STATUS',
'OBS_VALUE',
'UNIT_MEASURE',
'UNIT_MULT',
'BASE_PERIOD',
'TIME_DETAIL',
'SOURCE_DETAIL',
'SOURCE_DETAIL_DESC_AR',
'SOURCE_DETAIL_DESC_EN']]

# %%
x.head(5)
# Out:
#    GOAL GOAL_DESC_AR GOAL_DESC_EN TARGET TARGET_DESC_AR TARGET_DESC_EN  \
# 0   1.0          NaN       Goal 1      1            NaN            NaN
# 1   1.0          NaN          NaN    NaN            NaN            NaN
# 2   1.0          NaN          NaN    NaN            NaN            NaN
# 3   1.0          NaN          NaN    NaN            NaN            NaN
# 4   1.0          NaN          NaN    NaN            NaN            NaN
#
#   INDICATOR INDICATOR_CODE                             INDICATOR_CODE_DESC_AR  \
# 0       NaN        C010201    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 1       NaN        C010201    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 2       NaN        C010201    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 3       NaN        C010201    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
# 4       NaN        C010201    نسبة السكان الذين يعيشون دون خط الفقر الوطني...
#
#                               INDICATOR_CODE_DESC_EN          ...           \
# 0  Proportion of population living below the nati...          ...
# 1  Proportion of population living below the nati...          ...
# 2  Proportion of population living below the nati...          ...
# 3  Proportion of population living below the nati...          ...
# 4  Proportion of population living below the nati...          ...
#
#                                          OBS_COMMENT OBS_STATUS OBS_VALUE  \
# 0  The data represent households and not populati...          ?      26.2
# 1  The data represent households and not populati...        NaN      25.7
# 2  The data represent households and not populati...        NaN      25.8
# 3  The data represent households and not populati...        NaN      29.2
# 4  The data represent households and not populati...        NaN      19.4
#
#   UNIT_MEASURE UNIT_MULT BASE_PERIOD TIME_DETAIL  \
# 0            %         ?           ?           ?
# 1            %       NaN         NaN         NaN
# 2            %       NaN         NaN         NaN
# 3            %       NaN         NaN         NaN
# 4            %       NaN         NaN         NaN
#
#                                        SOURCE_DETAIL  SOURCE_DETAIL_DESC_AR  \
# 0  PCBS. Living Standards in the Palestinian Terr...                    NaN
# 1  PCBS. Living Standards in the Palestinian Terr...                    NaN
# 2  PCBS. Living Standards in the Palestinian Terr...                    NaN
# 3  PCBS. Living Standards in the Palestinian Terr...                    NaN
# 4  PCBS. Living Standards in the Palestinian Terr...                    NaN
#
#   SOURCE_DETAIL_DESC_EN
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 82 columns]

# %%
x.to_excel(output_dir + 'consolidated_MDT.xlsx',index=False, encoding='UTF-8')
