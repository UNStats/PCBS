# %% [markdown]
# # Development of SDG Matrix for PCBS

# %% [markdown]
# The may objective of the UNSD/DFID project technical mission to PCBS (from 31 March to 4 April 2019) is to support PCBS in setting up:
# - A working prototype of an SDG data platform
# - A workflow to update and maintain the SDG data platform prototype using, as much as possible, automation tools
#
# **Deliverables:**
# 1. A national SDG indicators matrix
#    - Indicator name
#    - Mapping to global SDG indicator framework
#    - Source
#    - Availability
# 2. A national SDG data structure definition
#    - Indicator code
#    - Indicator description
#    - Available disaggregations (dimensions)
#    - Available attributes
# 3. Data collection and validation templates
# 4. A repository of available SDG data,  including:
#    - A master version of the national DSD and Code Lists
#    - Set of SDG indicator tables following the national DSD
#    - Pivot/extended views of the SDG indicator tables, suitable for data dissemination
# 5. A repository of boundary data for the available geographic disaggregations
# 6. A repository of core metadata files and graphic design assets
# 7. A repository of python scripts for dataflow automation, which may include:
#    - Data pre-processing
#    - Creation of pivot/extended views of the SDG indicator tables for dissemination
#    - Linking of SDG indicator tables with geographic boundaries and publication into ArcGIS online

# %% [markdown]
# ## 1. Setup of working environment for this notebook

# %%
import pandas as pd
import os 

dir_path = os.path.dirname(os.path.realpath('__file__'))
print(dir_path)


input_dir = r'../SDG-Matrix/Input/'
print('data inputs dir: ' + input_dir)

output_dir = r'../SDG-Matrix/Output/'
print('outputs dir: ' + output_dir)
# Out:
# C:\Users\L.GonzalezMorales\Documents\GitHub\PCBS\notebooks
# data inputs dir: ../SDG-Matrix/Input/
# outputs dir: ../SDG-Matrix/Output/

# %% [markdown]
# ## 2. Develop SDG Matrix template

# %% [markdown]
# ## 2.1 Read `SDGsMatrix.csv` file provided by PCBS
#
# The `SDGsMatrix.csv` file contains the list of all SDG indicators

# %%
sdgMatrix_df = pd.read_csv(input_dir + 'SDGsMatrix.csv', encoding='UTF-8', 
                              dtype={'Goal_ID':str,
                                     'Goal_DescEn':str,
                                     'Goal_DescAr':str,
                                     'Target_ID':str,
                                     'Target_DescEn':str,
                                     'Target_DescAr': str,
                                     'Indicator_NL': str,
                                     'Indicator_Code': str,
                                     'Indicator_descEn': str,
                                     'Indicator_descAr': str,
                                     'Subindicator_Code': str, 
                                     'Subindicator_DescEn': str,
                                     'Subindicator_DescAr': str })
sdgMatrix_df.head(5)
# Out:
#   Goal_ID Goal_DescEn       Goal_DescAr Target_ID  \
# 0       1  No poverty  القضاء على الفقر       1.1
# 1       1  No poverty  القضاء على الفقر       1.1
# 2       1  No poverty  القضاء على الفقر       1.1
# 3       1  No poverty  القضاء على الفقر       1.1
# 4       1  No poverty  القضاء على الفقر       1.1
#
#                                        Target_DescEn  \
# 0  By 2030, eradicate extreme poverty for all peo...
# 1  By 2030, eradicate extreme poverty for all peo...
# 2  By 2030, eradicate extreme poverty for all peo...
# 3  By 2030, eradicate extreme poverty for all peo...
# 4  By 2030, eradicate extreme poverty for all peo...
#
#                                        Target_DescAr Indicator_NL  \
# 0  القضاء على الفقر المدقع للناس أجمعين أينما كان...   1.1.1
# 1  القضاء على الفقر المدقع للناس أجمعين أينما كان...   1.1.1
# 2  القضاء على الفقر المدقع للناس أجمعين أينما كان...   1.1.1
# 3  القضاء على الفقر المدقع للناس أجمعين أينما كان...   1.1.1
# 4  القضاء على الفقر المدقع للناس أجمعين أينما كان...   1.1.1
#
#   Indicator_Code                                   Indicator_descEn  \
# 0     C010101      Proportion of population below the internatio...
# 1     C010101      Proportion of population below the internatio...
# 2     C010101      Proportion of population below the internatio...
# 3     C010101      Proportion of population below the internatio...
# 4     C010101      Proportion of population below the internatio...
#
#                                     Indicator_descAr      ...        \
# 0  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 1  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 2  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 3  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 4  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
#
#   InternetSpeed_DescEn InternetSpeed_DescAr OBS_VALUE  UNIT_MULT  \
# 0                  NaN                  NaN       NaN        NaN
# 1                  NaN                  NaN       NaN        NaN
# 2                  NaN                  NaN       NaN        NaN
# 3                  NaN                  NaN       NaN        NaN
# 4                  NaN                  NaN       NaN        NaN
#
#    UNIT_MEASURE OBS_STATUS  TIME_DETAIL COMMENT_OBS BASE_PER  SOURCE_DETAIL
# 0           NaN        NaN          NaN         NaN      NaN            NaN
# 1           NaN        NaN          NaN         NaN      NaN            NaN
# 2           NaN        NaN          NaN         NaN      NaN            NaN
# 3           NaN        NaN          NaN         NaN      NaN            NaN
# 4           NaN        NaN          NaN         NaN      NaN            NaN
#
# [5 rows x 76 columns]

# %% [markdown]
# *Check number of rows and columns:*

# %%
print(sdgMatrix_df.shape)
print(sdgMatrix_df.columns)
# Out:
# (47439, 76)
# Index(['Goal_ID', 'Goal_DescEn', 'Goal_DescAr', 'Target_ID', 'Target_DescEn',
#        'Target_DescAr', 'Indicator_NL', 'Indicator_Code', 'Indicator_descEn',
#        'Indicator_descAr', 'Subindicator_Code', 'Subindicator_DescEn',
#        'Subindicator_DescAr', 'TIME_PERIOD', 'REF_AREA', 'REF_AREA_DESC_EN',
#        'REF_AREA_DESC_AR', 'SEX', 'SEX_DESC_EN', 'SEX_DESC_AR', 'AGE',
#        'Age_DescEn', 'Age_DescAr', 'URBANISATION', 'Urbanisation_DescEn',
#        'Urbanisation_DescAr', 'EDUCATION_LEV', 'Education_DescEn',
#        'Education_DescAr', 'DISABILITY_STATUS', 'DisabilityStatus_DescEn',
#        'DisabilityStatus_DescAr', 'OCCUPATION', 'Occupation_DescEn',
#        'Occupation_DescAr', 'Sector', 'Sector_DescEn', 'Sector_DescAr',
#        'AreaOfStudy', 'AreaOfStudy_DescEn', 'AreaOfStudy_DescAr',
#        'TypeOfViolence', 'TypeOfViolence_DescEn', 'TypeOfViolence_DescAr',
#        'EmploymentStatus', 'EmploymentStatus_DescEn',
#        'EmploymentStatus_DescAr', 'PregnancyStatus', 'PregnancyStatus_DescEn',
#        'PregnancyStatus_DescAr', 'WorkingInjuryStatus',
#        'WorkingInjuryStatus_DescEn', 'WorkingInjuryStatus_DescAr',
#        'PovertyStatus', 'PovertyStatus_DescEn', 'PovertyStatus_DescAr',
#        'YearsOfSchooling', 'YearsOfSchooling_DescEn',
#        'YearsOfSchooling_DescAr', 'MobileNetworkTechnology',
#        'MobileNetworkTechnology_DescEn', 'MobileNetworkTechnology_DescAr',
#        'EcosystemType', 'EcosystemType_DescEn', 'EcosystemType_DescAr',
#        'InternetSpeed', 'InternetSpeed_DescEn', 'InternetSpeed_DescAr',
#        'OBS_VALUE', 'UNIT_MULT', 'UNIT_MEASURE', 'OBS_STATUS', 'TIME_DETAIL',
#        'COMMENT_OBS', 'BASE_PER', 'SOURCE_DETAIL'],
#       dtype='object')

# %% [markdown]
# ## 2.2 Identify dimensions
#
# The template includes 18 coded dimensions (in addition to **`TIME_PERIOD`**), namely:
# - **`REF_AREA`**: Reference area (geographic area)
# - **`SEX`**: Male/female
# - **`URBANISATION`**: Urban/rural
# - **`EDUCATION_LEV`**: Education level
# - **`DISABILITY_STATUS`**: Disability status
# - **`OCCUPATION`**: Occupation
# - **`SECTOR`**: Economic activity
# - **`STUDY_AREA`**: Area of study
# - **`VIOLENCE_TYPE`**: Type of violence
# - **`EMPLOYMENT_STATUS`**: Employment status
# - **`PREGNANCY_STATUS`**: Pregnancy status
# - **`WORKING_INJURY_STATUS`**: Working injury status
# - **`POVERTY_STATUS`**: Poverty status
# - **`SCHOOLING_YEARS`**: Years of schooling
# - **`MOBILE_NETWORK_TECHNOLOGY`**: Mobile network technology
# - **`ECOSYSTEM_TYPE`**: Type of ecosystem
# - **`INTERNET_SPEED`**: Internet speed
#
# In addition to the dimension codes, the matrix also includes English and Arabic description for each of them.

# %% [markdown]
# For the sake of standardization, the dimension columns of the draft matrix will be written in all-capital letters:

# %%
sdgMatrix_df = sdgMatrix_df.rename(columns = {'Age_DescEn':'AGE_DESC_EN', 
                                                    'Age_DescAr':'AGE_DESC_AR',
                                                    'Urbanisation_DescEn': 'URBANISATION_DESC_EN', 
                                                    'Urbanisation_DescAr': 'URBANISATION_DESC_AR',
                                                    'Education_DescEn': 'EDUCATION_LEV_DESC_EN', 
                                                    'Education_DescAr': 'EDUCATION_LEV_DESC_AR',
                                                    'DisabilityStatus_DescEn': 'DISABILITY_STATUS_DESC_EN', 
                                                    'DisabilityStatus_DescAr': 'DISABILITY_STATUS_DESC_AR',
                                                    'Occupation_DescEn': 'OCCUPATION_DESC_EN', 
                                                    'Occupation_DescAr': 'OCCUPATION_DESC_AR',
                                                    'Sector': 'SECTOR', 
                                                    'Sector_DescEn': 'SECTOR_DESC_EN', 
                                                    'Sector_DescAr': 'SECTOR_DESC_AR',
                                                    'AreaOfStudy': 'STUDY_AREA', 
                                                    'AreaOfStudy_DescEn': 'STUDY_AREA_DESC_EN', 
                                                    'AreaOfStudy_DescAr': 'STUDY_AREA_DESC_AR',
                                                    'TypeOfViolence': 'VIOLENCE_TYPE', 
                                                    'TypeOfViolence_DescEn': 'VIOLENCE_TYPE_DESC_EN', 
                                                    'TypeOfViolence_DescAr': 'VIOLENCE_TYPE_DESC_AR',
                                                    'EmploymentStatus': 'EMPLOYMENT_STATUS', 
                                                    'EmploymentStatus_DescEn': 'EMPLOYMENT_STATUS_DESC_EN', 
                                                    'EmploymentStatus_DescAr': 'EMPLOYMENT_STATUS_DESC_AR', 
                                                    'PregnancyStatus': 'PREGNANCY_STATUS', 
                                                    'PregnancyStatus_DescEn': 'PREGNANCY_STATUS_DESC_EN', 
                                                    'PregnancyStatus_DescAr': 'PREGNANCY_STATUS_DESC_AR',
                                                    'WorkingInjuryStatus': 'WORKING_INJURY_STATUS', 
                                                    'WorkingInjuryStatus_DescEn': 'WORKING_INJURY_STATUS_DESC_EN', 
                                                    'WorkingInjuryStatus_DescAr': 'WORKING_INJURY_STATUS_DESC_AR',
                                                    'PovertyStatus': 'POVERTY_STATUS', 
                                                    'PovertyStatus_DescEn': 'POVERTY_STATUS_DESC_EN', 
                                                    'PovertyStatus_DescAr': 'POVERTY_STATUS_DESC_AR',
                                                    'YearsOfSchooling': 'SCHOOLING_YEARS', 
                                                    'YearsOfSchooling_DescEn': 'SCHOOLING_YEARS_DESC_EN', 
                                                    'YearsOfSchooling_DescAr': 'SCHOOLING_YEARS_DESC_AR', 
                                                    'MobileNetworkTechnology': 'MOBILE_NETWORK_TECHNOLOGY', 
                                                    'MobileNetworkTechnology_DescEn': 'MOBILE_NETWORK_TECHNOLOGY_DESC_EN', 
                                                    'MobileNetworkTechnology_DescAr': 'MOBILE_NETWORK_TECHNOLOGY_DESC_AR',
                                                    'EcosystemType': 'ECOSYSTEM_TYPE', 
                                                    'EcosystemType_DescEn': 'ECOSYSTEM_TYPE_DESC_EN', 
                                                    'EcosystemType_DescAr': 'ECOSYSTEM_TYPE_DESC_AR',
                                                    'InternetSpeed': 'INTERNET_SPEED', 
                                                    'InternetSpeed_DescEn': 'INTERNET_SPEED_DESC_EN', 
                                                    'InternetSpeed_DescAr': 'INTERNET_SPEED_DESC_AR'})

# %% [markdown]
# Use capital letter for all other column headings:

# %%
sdgMatrix_df = sdgMatrix_df.rename(columns = {'Goal_ID': 'GOAL_ID', 
                                              'Goal_DescEn': 'GOAL_DESC_EN', 
                                              'Goal_DescAr': 'GOAL_DESC_AR',
                                              'Target_ID': 'TARGET_ID', 
                                              'Target_DescEn': 'TARGET_DESC_EN',
                                              'Target_DescAr': 'TARGET_DESC_AR', 
                                              'Indicator_NL': 'INDICATOR_LABEL', 
                                              'Indicator_Code': 'INDICATOR_ID', 
                                              'Indicator_descEn': 'INDICATOR_DESC_EN',
                                              'Indicator_descAr': 'INDICATOR_DESC_AR', 
                                              'Subindicator_Code': 'SUBINDICATOR_ID',
                                              'Subindicator_DescEn': 'SUBINDICATOR_DESC_EN',
                                              'Subindicator_DescAr': 'SUBINDICATOR_DESC_AR'})

# %%
sdgMatrix_df.head(5)
# Out:
#   GOAL_ID GOAL_DESC_EN      GOAL_DESC_AR TARGET_ID  \
# 0       1   No poverty  القضاء على الفقر       1.1
# 1       1   No poverty  القضاء على الفقر       1.1
# 2       1   No poverty  القضاء على الفقر       1.1
# 3       1   No poverty  القضاء على الفقر       1.1
# 4       1   No poverty  القضاء على الفقر       1.1
#
#                                       TARGET_DESC_EN  \
# 0  By 2030, eradicate extreme poverty for all peo...
# 1  By 2030, eradicate extreme poverty for all peo...
# 2  By 2030, eradicate extreme poverty for all peo...
# 3  By 2030, eradicate extreme poverty for all peo...
# 4  By 2030, eradicate extreme poverty for all peo...
#
#                                       TARGET_DESC_AR INDICATOR_LABEL  \
# 0  القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 1  القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 2  القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 3  القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 4  القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
#
#   INDICATOR_ID                                  INDICATOR_DESC_EN  \
# 0   C010101      Proportion of population below the internatio...
# 1   C010101      Proportion of population below the internatio...
# 2   C010101      Proportion of population below the internatio...
# 3   C010101      Proportion of population below the internatio...
# 4   C010101      Proportion of population below the internatio...
#
#                                    INDICATOR_DESC_AR      ...        \
# 0  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 1  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 2  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 3  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
# 4  نسبة السكان الذين يعيشون دون خط الفقر الدولي ب...      ...
#
#   INTERNET_SPEED_DESC_EN INTERNET_SPEED_DESC_AR OBS_VALUE  UNIT_MULT  \
# 0                    NaN                    NaN       NaN        NaN
# 1                    NaN                    NaN       NaN        NaN
# 2                    NaN                    NaN       NaN        NaN
# 3                    NaN                    NaN       NaN        NaN
# 4                    NaN                    NaN       NaN        NaN
#
#    UNIT_MEASURE OBS_STATUS  TIME_DETAIL COMMENT_OBS BASE_PER  SOURCE_DETAIL
# 0           NaN        NaN          NaN         NaN      NaN            NaN
# 1           NaN        NaN          NaN         NaN      NaN            NaN
# 2           NaN        NaN          NaN         NaN      NaN            NaN
# 3           NaN        NaN          NaN         NaN      NaN            NaN
# 4           NaN        NaN          NaN         NaN      NaN            NaN
#
# [5 rows x 76 columns]

# %%
sdgMatrix_subindicators = sdgMatrix_df.copy()

sdgMatrix_subindicators = sdgMatrix_subindicators.drop(['TIME_PERIOD'], axis=1).drop_duplicates

print(sdgMatrix_subindicators)
# Out:
# <bound method DataFrame.drop_duplicates of       GOAL_ID                GOAL_DESC_EN                 GOAL_DESC_AR  \
# 0           1                  No poverty             القضاء على الفقر
# 1           1                  No poverty             القضاء على الفقر
# 2           1                  No poverty             القضاء على الفقر
# 3           1                  No poverty             القضاء على الفقر
# 4           1                  No poverty             القضاء على الفقر
# 5           1                  No poverty             القضاء على الفقر
# 6           1                  No poverty             القضاء على الفقر
# 7           1                  No poverty             القضاء على الفقر
# 8           1                  No poverty             القضاء على الفقر
# 9           1                  No poverty             القضاء على الفقر
# 10          1                  No poverty             القضاء على الفقر
# 11          1                  No poverty             القضاء على الفقر
# 12          1                  No poverty             القضاء على الفقر
# 13          1                  No poverty             القضاء على الفقر
# 14          1                  No poverty             القضاء على الفقر
# 15          1                  No poverty             القضاء على الفقر
# 16          1                  No poverty             القضاء على الفقر
# 17          1                  No poverty             القضاء على الفقر
# 18          1                  No poverty             القضاء على الفقر
# 19          1                  No poverty             القضاء على الفقر
# 20          1                  No poverty             القضاء على الفقر
# 21          1                  No poverty             القضاء على الفقر
# 22          1                  No poverty             القضاء على الفقر
# 23          1                  No poverty             القضاء على الفقر
# 24          1                  No poverty             القضاء على الفقر
# 25          1                  No poverty             القضاء على الفقر
# 26          1                  No poverty             القضاء على الفقر
# 27          1                  No poverty             القضاء على الفقر
# 28          1                  No poverty             القضاء على الفقر
# 29          1                  No poverty             القضاء على الفقر
# ...       ...                         ...                          ...
# 47409      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47410      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47411      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47412      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47413      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47414      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47415      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47416      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47417      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47418      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47419      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47420      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47421      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47422      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47423      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47424      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47425      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47426      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47427      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47428      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47429      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47430      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47431      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47432      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47433      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47434      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47435      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47436      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47437      17  Partnerships for the Goals  عقد الشراكات لتحقيق الاهداف
# 47431      17.9  Capacity-building:   17.9 Enhance internationa...
# 47432      17.9  Capacity-building:   17.9 Enhance internationa...
# 47433      17.9  Capacity-building:   17.9 Enhance internationa...
# 47434      17.9  Capacity-building:   17.9 Enhance internationa...
# 47435      17.9  Capacity-building:   17.9 Enhance internationa...
# 47436      17.9  Capacity-building:   17.9 Enhance internationa...
# 47437      17.9  Capacity-building:   17.9 Enhance internationa...
# 47438      17.9  Capacity-building:   17.9 Enhance internationa...
#
#                                           TARGET_DESC_AR INDICATOR_LABEL  \
# 0      القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 1      القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 2      القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 3      القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 4      القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 5      القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 6      القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 7      القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 8      القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 9      القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 10     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 11     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 12     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 13     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 14     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 15     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 16     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 17     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 18     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 19     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 20     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 21     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 22     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 23     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 24     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 25     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 26     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 27     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 28     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# 29     القضاء على الفقر المدقع للناس أجمعين أينما كان...      1.1.1
# ...                                                  ...             ...
# 47409                                                NaN      17.9.1
# 47410                                                NaN      17.9.1
# 47411                                                NaN      17.9.1
# 47412                                                NaN      17.9.1
# 47413                                                NaN      17.9.1
# 47414                                                NaN      17.9.1
# 47415                                                NaN      17.9.1
# 47416                                                NaN      17.9.1
# 47417                                                NaN      17.9.1
# 47418                                                NaN      17.9.1
# 47419                                                NaN      17.9.1
# 47420                                                NaN      17.9.1
# 47421                                                NaN      17.9.1
# 47422                                                NaN      17.9.1
# 47423                                                NaN      17.9.1
# 47424                                                NaN      17.9.1
# 47425                                                NaN      17.9.1
# 47426                                                NaN      17.9.1
# 47427                                                NaN      17.9.1
# 47428                                                NaN      17.9.1
# 47429                                                NaN      17.9.1
# 47430                                                NaN      17.9.1
# 47431                                                NaN      17.9.1
# 47432                                                NaN      17.9.1
# 47433                                                NaN      17.9.1
# 47434                                                NaN      17.9.1
# 47435                                                NaN      17.9.1
# 47436                                                NaN      17.9.1
# 47437                                                NaN      17.9.1
# 47438                                                NaN      17.9.1
#
#       INDICATOR_ID                                  INDICATOR_DESC_EN  \
# 0       C010101      Proportion of population below the internatio...
# 1       C010101      Proportion of population below the internatio...
# 2       C010101      Proportion of population below the internatio...
# 3       C010101      Proportion of population below the internatio...
# 4       C010101      Proportion of population below the internatio...
# 5       C010101      Proportion of population below the internatio...
# 6       C010101      Proportion of population below the internatio...
# 7       C010101      Proportion of population below the internatio...
# 8       C010101      Proportion of population below the internatio...
# 9       C010101      Proportion of population below the internatio...
# 10      C010101      Proportion of population below the internatio...
# 11      C010101      Proportion of population below the internatio...
# 12      C010101      Proportion of population below the internatio...
# 13      C010101      Proportion of population below the internatio...
# 14      C010101      Proportion of population below the internatio...
# 15      C010101      Proportion of population below the internatio...
# 16      C010101      Proportion of population below the internatio...
# 17      C010101      Proportion of population below the internatio...
# 18      C010101      Proportion of population below the internatio...
# 19      C010101      Proportion of population below the internatio...
# 20      C010101      Proportion of population below the internatio...
# 21      C010101      Proportion of population below the internatio...
# 22      C010101      Proportion of population below the internatio...
# 23      C010101      Proportion of population below the internatio...
# 24      C010101      Proportion of population below the internatio...
# 25      C010101      Proportion of population below the internatio...
# 26      C010101      Proportion of population below the internatio...
# 27      C010101      Proportion of population below the internatio...
# 28      C010101      Proportion of population below the internatio...
# 7                        NaN                    NaN       NaN        NaN
# 8                        NaN                    NaN       NaN        NaN
# 9                        NaN                    NaN       NaN        NaN
# 10                       NaN                    NaN       NaN        NaN
# 11                       NaN                    NaN       NaN        NaN
# 12                       NaN                    NaN       NaN        NaN
# 13                       NaN                    NaN       NaN        NaN
# 14                       NaN                    NaN       NaN        NaN
# 15                       NaN                    NaN       NaN        NaN
# 16                       NaN                    NaN       NaN        NaN
# 17                       NaN                    NaN       NaN        NaN
# 18                       NaN                    NaN       NaN        NaN
# 19                       NaN                    NaN       NaN        NaN
# 20                       NaN                    NaN       NaN        NaN
# 21                       NaN                    NaN       NaN        NaN
# 22                       NaN                    NaN       NaN        NaN
# 23                       NaN                    NaN       NaN        NaN
# 24                       NaN                    NaN       NaN        NaN
# 25                       NaN                    NaN       NaN        NaN
# 26                       NaN                    NaN       NaN        NaN
# 27                       NaN                    NaN       NaN        NaN
# 28                       NaN                    NaN       NaN        NaN
# 29                       NaN                    NaN       NaN        NaN
# ...                      ...                    ...       ...        ...
# 47409                    NaN                    NaN       NaN        NaN
# 47410                    NaN                    NaN       NaN        NaN
# 47411                    NaN                    NaN       NaN        NaN
# 47412                    NaN                    NaN       NaN        NaN
# 47413                    NaN                    NaN       NaN        NaN
# 47414                    NaN                    NaN       NaN        NaN
# 47415                    NaN                    NaN       NaN        NaN
# 47416                    NaN                    NaN       NaN        NaN
# 47417                    NaN                    NaN       NaN        NaN
# 47418                    NaN                    NaN       NaN        NaN
# 47419                    NaN                    NaN       NaN        NaN
# 47420                    NaN                    NaN       NaN        NaN
# 47421                    NaN                    NaN       NaN        NaN
# 47422                    NaN                    NaN       NaN        NaN
# 47423                    NaN                    NaN       NaN        NaN
# 47424                    NaN                    NaN       NaN        NaN
# 47425                    NaN                    NaN       NaN        NaN
# 47426                    NaN                    NaN       NaN        NaN
# 47427                    NaN                    NaN       NaN        NaN
# 47428                    NaN                    NaN       NaN        NaN
# 47429                    NaN                    NaN       NaN        NaN
# 47430                    NaN                    NaN       NaN        NaN
# 47431                    NaN                    NaN       NaN        NaN
# 47432                    NaN                    NaN       NaN        NaN
# 47433                    NaN                    NaN       NaN        NaN
# 47434                    NaN                    NaN       NaN        NaN
# 47435                    NaN                    NaN       NaN        NaN
# 47436                    NaN                    NaN       NaN        NaN
# 47437                    NaN                    NaN       NaN        NaN
# 47438                    NaN                    NaN       NaN        NaN
#
#       UNIT_MEASURE  OBS_STATUS TIME_DETAIL COMMENT_OBS  BASE_PER  \
# 0              NaN         NaN         NaN         NaN       NaN
# 1              NaN         NaN         NaN         NaN       NaN
# 2              NaN         NaN         NaN         NaN       NaN
# 3              NaN         NaN         NaN         NaN       NaN
# 4              NaN         NaN         NaN         NaN       NaN
# 5              NaN         NaN         NaN         NaN       NaN
# 6              NaN         NaN         NaN         NaN       NaN
# 7              NaN         NaN         NaN         NaN       NaN
# 8              NaN         NaN         NaN         NaN       NaN
# 9              NaN         NaN         NaN         NaN       NaN
# 10             NaN         NaN         NaN         NaN       NaN
# 11             NaN         NaN         NaN         NaN       NaN
# 12             NaN         NaN         NaN         NaN       NaN
# 13             NaN         NaN         NaN         NaN       NaN
# 14             NaN         NaN         NaN         NaN       NaN
# 15             NaN         NaN         NaN         NaN       NaN
# 16             NaN         NaN         NaN         NaN       NaN
# 17             NaN         NaN         NaN         NaN       NaN
# 18             NaN         NaN         NaN         NaN       NaN
# 19             NaN         NaN         NaN         NaN       NaN
# 20             NaN         NaN         NaN         NaN       NaN
# 21             NaN         NaN         NaN         NaN       NaN
# 22             NaN         NaN         NaN         NaN       NaN
# 23             NaN         NaN         NaN         NaN       NaN
# 24             NaN         NaN         NaN         NaN       NaN
# 25             NaN         NaN         NaN         NaN       NaN
# 26             NaN         NaN         NaN         NaN       NaN
# 27             NaN         NaN         NaN         NaN       NaN
# 28             NaN         NaN         NaN         NaN       NaN
# 29             NaN         NaN         NaN         NaN       NaN
# ...            ...         ...         ...         ...       ...
# 47409          NaN         NaN         NaN         NaN       NaN
# 47410          NaN         NaN         NaN         NaN       NaN
# 47411          NaN         NaN         NaN         NaN       NaN
# 47412          NaN         NaN         NaN         NaN       NaN
# 47413          NaN         NaN         NaN         NaN       NaN
# 47414          NaN         NaN         NaN         NaN       NaN
# 47415          NaN         NaN         NaN         NaN       NaN
# 47416          NaN         NaN         NaN         NaN       NaN
# 47417          NaN         NaN         NaN         NaN       NaN
# 47418          NaN         NaN         NaN         NaN       NaN
# 47419          NaN         NaN         NaN         NaN       NaN
# 47420          NaN         NaN         NaN         NaN       NaN
# 47421          NaN         NaN         NaN         NaN       NaN
# 47422          NaN         NaN         NaN         NaN       NaN
# 47423          NaN         NaN         NaN         NaN       NaN
# 47424          NaN         NaN         NaN         NaN       NaN
# 47425          NaN         NaN         NaN         NaN       NaN
# 47426          NaN         NaN         NaN         NaN       NaN
# 47427          NaN         NaN         NaN         NaN       NaN
# 47428          NaN         NaN         NaN         NaN       NaN
# 47429          NaN         NaN         NaN         NaN       NaN
# 47430          NaN         NaN         NaN         NaN       NaN
# 47431          NaN         NaN         NaN         NaN       NaN
# 47432          NaN         NaN         NaN         NaN       NaN
# 47433          NaN         NaN         NaN         NaN       NaN
# 47434          NaN         NaN         NaN         NaN       NaN
# 47435          NaN         NaN         NaN         NaN       NaN
# 47436          NaN         NaN         NaN         NaN       NaN
# 47437          NaN         NaN         NaN         NaN       NaN
# 47438          NaN         NaN         NaN         NaN       NaN
#
#        SOURCE_DETAIL
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
# ...              ...
# 47409            NaN
# 47410            NaN
# 47411            NaN
# 47412            NaN
# 47413            NaN
# 47414            NaN
# 47415            NaN
# 47416            NaN
# 47417            NaN
# 47418            NaN
# 47419            NaN
# 47420            NaN
# 47421            NaN
# 47422            NaN
# 47423            NaN
# 47424            NaN
# 47425            NaN
# 47426            NaN
# 47427            NaN
# 47428            NaN
# 47429            NaN
# 47430            NaN
# 47431            NaN
# 47432            NaN
# 47433            NaN
# 47434            NaN
# 47435            NaN
# 47436            NaN
# 47437            NaN
# 47438            NaN
#
# [47439 rows x 75 columns]>
